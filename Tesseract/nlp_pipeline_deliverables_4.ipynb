# %% [markdown]
# # NLP Pipeline — Phase 1
# ### Image OCR → Text Cleaning → Tokenisation → Stopwords → Lemmatisation → NER → Key Phrases → Dependency Parsing
# ---

# %% [markdown]
# ## Imports

# %%
# !pip install --upgrade certifi
# Out:
# Requirement already satisfied: certifi in /Users/eamon.myles/Desktop/venv/ocr_env/lib/python3.12/site-packages (2026.4.22)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
import ssl
import certifi

ssl._create_default_https_context = lambda: ssl.create_default_context(cafile=certifi.where())

# %%
# ── Image / OCR ───────────────────────────────────────────────────────────
import cv2
import pytesseract

# ── Core NLP ──────────────────────────────────────────────────────────────
import spacy
from spacy import displacy
from IPython.display import display, HTML

# ── NLTK ──────────────────────────────────────────────────────────────────
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords',  quiet=True)
nltk.download('punkt_tab',  quiet=True)
nltk.download('wordnet',    quiet=True)

# ── Utilities ─────────────────────────────────────────────────────────────
import matplotlib.pyplot as plt

# Load spaCy model
nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1000)>
# [nltk_data] Error loading punkt_tab: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1000)>
# [nltk_data] Error loading wordnet: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1000)>

# %% [markdown]
# ---
# ## 0. Source Document — Render PDF to PNG
#
# The source document for this pipeline is an academic paper supplied as PDF:
#
# > **Predicting County-Level Homeownership Rates in the United States Using
# > Machine Learning and Historical ACS Data**
#
# OpenCV's `cv2.imread` (the entry point used throughout the WK6 lab) cannot
# read PDFs directly, so this cell renders **page 1** of the PDF to a PNG at
# 200 DPI once, and the rest of the notebook treats `paper_p1.png` as the
# primary image — the WK6-lab pipeline (`cv2.imread`, `cv2.cvtColor`,
# `cv2.GaussianBlur`, `cv2.threshold`, `cv2.rectangle`, `cv2.putText`,
# `cv2.imwrite`) is then unchanged from this point on.
#
# *Reference: PyMuPDF (`fitz`) — https://pymupdf.readthedocs.io/en/latest/*

# %%
# ── Render page 1 of the source PDF to a 200 DPI PNG ──────────────────────
# Two PDF rendering libraries are tried in order so the cell survives
# whichever one happens to be installed locally:
#   1. pypdfium2  (Google PDFium binding, no system deps)        -- preferred
#   2. PyMuPDF / fitz  (Artifex MuPDF binding)                   -- fallback
# If neither is present, pypdfium2 is pip-installed.
#
# References:
#   pypdfium2 — https://pypdfium2.readthedocs.io/en/stable/
#   PyMuPDF   — https://pymupdf.readthedocs.io/en/latest/
#
# This is the only step in the notebook that uses a PDF library; from here
# on the WK6 lab pattern (cv2.imread, cv2.cvtColor, ...) takes over unchanged.
import os, sys, subprocess

PDF_FILE     = 'Predicting_County_Level_Homeownership_Rates_in_the_United_States_Using_Machine_Learning_and_Historical_ACS_Data.pdf'
PAGE_NUM     = 4          # 0-based -> page 5
DPI          = 200
RENDERED_PNG = 'paper_p1.png'

if not os.path.exists(PDF_FILE):
    raise FileNotFoundError(
        f"Could not find '{PDF_FILE}'. "
        "Make sure the PDF is in the same directory as this notebook."
    )

_render_lib = None
try:
    import pypdfium2 as _pdfium
    _render_lib = 'pypdfium2'
except ImportError:
    try:
        import fitz as _fitz
        _render_lib = 'fitz'
    except ImportError:
        print('No PDF library found; installing pypdfium2...')
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--quiet', 'pypdfium2'])
        import pypdfium2 as _pdfium
        _render_lib = 'pypdfium2'

if _render_lib == 'pypdfium2':
    _pdf  = _pdfium.PdfDocument(PDF_FILE)
    _img  = _pdf[PAGE_NUM].render(scale=DPI / 72).to_pil()
    _img.save(RENDERED_PNG)
    _w, _h = _img.width, _img.height
    _pdf.close()
else:  # fitz / PyMuPDF
    _doc = _fitz.open(PDF_FILE)
    _pix = _doc[PAGE_NUM].get_pixmap(
        matrix=_fitz.Matrix(DPI / 72, DPI / 72), alpha=False
    )
    _pix.save(RENDERED_PNG)
    _w, _h = _pix.width, _pix.height
    _doc.close()

print(f'Rendered page {PAGE_NUM + 1} of {PDF_FILE}  (using {_render_lib})')
print(f'  -> {RENDERED_PNG}  ({_w} x {_h} px @ {DPI} DPI)')
# Out:
# Rendered page 5 of Predicting_County_Level_Homeownership_Rates_in_the_United_States_Using_Machine_Learning_and_Historical_ACS_Data.pdf  (using fitz)
#   -> paper_p1.png  (1700 x 2200 px @ 200 DPI)

# %% [markdown]
# ---
# ## Image Input with OCR

# %%
# ── Load primary document image ─────────────────────────────────────────
# This image is shared between Phase 1 (OCR + NLP) and Phase 2 (image processing)
# so the pipeline produces a unified multi-modal view of one document.
# cv2.imread / cv2.cvtColor pattern: WK6 Lab Code.
PRIMARY_IMAGE = 'paper_p1.png'   # page 1 of the homeownership-rates paper, rendered from PDF at 200 DPI (see Sec. 0)
IMAGE_FILE    = PRIMARY_IMAGE    # kept for backwards-compat with downstream cells

img = cv2.imread(IMAGE_FILE)

if img is None:
    raise FileNotFoundError(
        f"Could not load '{IMAGE_FILE}'. "
        "Make sure the file is in the same directory as this notebook."
    )

print('Image loaded successfully.')
print(f'Shape (height, width, channels): {img.shape}')

# ── Display the document inline (BGR -> RGB conversion from WK6 lab) ─────
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8, 10))
plt.imshow(img_rgb)
plt.axis('off')
plt.title(f'Primary document: {IMAGE_FILE}', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Image loaded successfully.
# Shape (height, width, channels): (2200, 1700, 3)

# %%
# ── OCR with Tesseract ────────────────────────────────────────────────────
# --oem 1  = LSTM neural network engine (Tesseract 5)
# --psm 6  = assume a uniform block of text
custom_config = r'--oem 1 --psm 6'

ocr_text = pytesseract.image_to_string(img, config=custom_config)

print('=== RAW OCR OUTPUT ===')
print(ocr_text)
# Out:
# === RAW OCR OUTPUT ===
# someonnersip rte prev XGBoost Feature Importance (Enhanced with Historical Features) Change in County Homeownership Rate (2019-2022)
# peptone ony Pec Change in Homeownership
# ia Fig. 11. Evolution of homeownership
# Fig. 10. Random Forest feature importance as the most influential factors. These results highlight the
# importance of both historical persistence and broader socioe-
# conomic conditions in shaping county-level homeownership
# and decreases highlights the heterogeneous nature of housing patterns. In terms of model performance, Random Forest
# market dynamics, suggesting that local economic conditions, achieved the highest predictive accuracy (R? = 0.880),
# demographic trends, and housing supply constraints likely followed closely by Gradient Boosting (R? = 0.8673) and
# contributed to differing outcomes across counties. Neural Networks (R? = 0.770). These findings suggest that
# ensemble tree-based models are particularly well-suited for
# US County Homeownership Rate (2022 ACS) tabular socioeconomic data with nonlinear interactions, while
# omsounesnpaae | HUFal networks can still provide strong predictions but may
# be constrained by dataset size and feature dimensionality.
# * e In general, the results demonstrate that integrating historical
# “ features into predictive models not only improves accuracy but
# ” fo also provides valuable insights into the drivers of county-level
# , 02 homeownership, offering practical implications for policymak-
# = ~ : 5 ers and regional planners interested in housing stability and
# economic development. However, several limitations exist:
# e Only two time periods were analysed
# e Spatial dependencies were not modelled
# US County Homeownership Rate (2019 ACS) e ACS estimates contain sampling variability
# Homeownership Rate
# ee VIII. CONCLUSION
# x se This study developed a machine learning framework to
# predict U.S. county-level homeownership rates using ACS
# . A ws, ” data. The results demonstrate that county-level homeownership
# ~ ° ° can be predicted with high accuracy using socioeconomic, de-
# mographic, and housing characteristics. Among the evaluated
# models, Random Forest achieved the strongest performance
# Based on the results of this study, it is clear that county-level (R? = 0.880), outperforming both neural network and XG-
# homeownership rates in the United States can be effectively Boost models and highlighting the effectiveness of ensemble
# predicted using a combination of current and historical socioe- ee methods for structured socioeconomic data.
# conomic, demographic, and housing characteristics. All three Feature importance analysis identified prior-year homeown-
# machine learning models evaluated—Neural Networks, Ran- ership rates as the most influential predictor of homeownership
# dom Forest, and Gradient Boosting (XGBoost)—demonstrated outcomes. These findings provide insight into the structural
# strong predictive performance, with R? values ranging from drivers of homeownership and offer actionable information for
# 0.770 to 0.880, indicating that these features capture sub- policymakers and housing planners.
# stantial variance in homeownership outcomes across counties. Future research could extend this work by incorporating
# Among the predictor variables, prior-year homeownership spatial econometric modelling to account for geographic de-
# rates, the interaction between poverty levels and housing pendencies and by leveraging longer temporal datasets to
# prices, population density, and educational attainment emerged better capture dynamic housing trends over time.

# %% [markdown]
# ---
# ## 1 Tokenisation
# ### 1a NLTK Tokenisation

# %%
# ── Tokenise the OCR text using NLTK word_tokenize ────────────────────────
text_tokens = word_tokenize(ocr_text)

print('=== NLTK TOKENS ===')
print(text_tokens)
print(f'\nTotal tokens: {len(text_tokens)}')
# Out:
# === NLTK TOKENS ===
# ['someonnersip', 'rte', 'prev', 'XGBoost', 'Feature', 'Importance', '(', 'Enhanced', 'with', 'Historical', 'Features', ')', 'Change', 'in', 'County', 'Homeownership', 'Rate', '(', '2019-2022', ')', 'peptone', 'ony', 'Pec', 'Change', 'in', 'Homeownership', 'ia', 'Fig', '.', '11', '.', 'Evolution', 'of', 'homeownership', 'Fig', '.', '10', '.', 'Random', 'Forest', 'feature', 'importance', 'as', 'the', 'most', 'influential', 'factors', '.', 'These', 'results', 'highlight', 'the', 'importance', 'of', 'both', 'historical', 'persistence', 'and', 'broader', 'socioe-', 'conomic', 'conditions', 'in', 'shaping', 'county-level', 'homeownership', 'and', 'decreases', 'highlights', 'the', 'heterogeneous', 'nature', 'of', 'housing', 'patterns', '.', 'In', 'terms', 'of', 'model', 'performance', ',', 'Random', 'Forest', 'market', 'dynamics', ',', 'suggesting', 'that', 'local', 'economic', 'conditions', ',', 'achieved', 'the', 'highest', 'predictive', 'accuracy', '(', 'R', '?', '=', '0.880', ')', ',', 'demographic', 'trends', ',', 'and', 'housing', 'supply', 'constraints', 'likely', 'followed', 'closely', 'by', 'Gradient', 'Boosting', '(', 'R', '?', '=', '0.8673', ')', 'and', 'contributed', 'to', 'differing', 'outcomes', 'across', 'counties', '.', 'Neural', 'Networks', '(', 'R', '?', '=', '0.770', ')', '.', 'These', 'findings', 'suggest', 'that', 'ensemble', 'tree-based', 'models', 'are', 'particularly', 'well-suited', 'for', 'US', 'County', 'Homeownership', 'Rate', '(', '2022', 'ACS', ')', 'tabular', 'socioeconomic', 'data', 'with', 'nonlinear', 'interactions', ',', 'while', 'omsounesnpaae', '|', 'HUFal', 'networks', 'can', 'still', 'provide', 'strong', 'predictions', 'but', 'may', 'be', 'constrained', 'by', 'dataset', 'size', 'and', 'feature', 'dimensionality', '.', '*', 'e', 'In', 'general', ',', 'the', 'results', 'demonstrate', 'that', 'integrating', 'historical', '“', 'features', 'into', 'predictive', 'models', 'not', 'only', 'improves', 'accuracy', 'but', '”', 'fo', 'also', 'provides', 'valuable', 'insights', 'into', 'the', 'drivers', 'of', 'county-level', ',', '02', 'homeownership', ',', 'offering', 'practical', 'implications', 'for', 'policymak-', '=', '~', ':', '5', 'ers', 'and', 'regional', 'planners', 'interested', 'in', 'housing', 'stability', 'and', 'economic', 'development', '.', 'However', ',', 'several', 'limitations', 'exist', ':', 'e', 'Only', 'two', 'time', 'periods', 'were', 'analysed', 'e', 'Spatial', 'dependencies', 'were', 'not', 'modelled', 'US', 'County', 'Homeownership', 'Rate', '(', '2019', 'ACS', ')', 'e', 'ACS', 'estimates', 'contain', 'sampling', 'variability', 'Homeownership', 'Rate', 'ee', 'VIII', '.', 'CONCLUSION', 'x', 'se', 'This', 'study', 'developed', 'a', 'machine', 'learning', 'framework', 'to', 'predict', 'U.S.', 'county-level', 'homeownership', 'rates', 'using', 'ACS', '.', 'A', 'ws', ',', '”', 'data', '.', 'The', 'results', 'demonstrate', 'that', 'county-level', 'homeownership', '~', '°', '°', 'can', 'be', 'predicted', 'with', 'high', 'accuracy', 'using', 'socioeconomic', ',', 'de-', 'mographic', ',', 'and', 'housing', 'characteristics', '.', 'Among', 'the', 'evaluated', 'models', ',', 'Random', 'Forest', 'achieved', 'the', 'strongest', 'performance', 'Based', 'on', 'the', 'results', 'of', 'this', 'study', ',', 'it', 'is', 'clear', 'that', 'county-level', '(', 'R', '?', '=', '0.880', ')', ',', 'outperforming', 'both', 'neural', 'network', 'and', 'XG-', 'homeownership', 'rates', 'in', 'the', 'United', 'States', 'can', 'be', 'effectively', 'Boost', 'models', 'and', 'highlighting', 'the', 'effectiveness', 'of', 'ensemble', 'predicted', 'using', 'a', 'combination', 'of', 'current', 'and', 'historical', 'socioe-', 'ee', 'methods', 'for', 'structured', 'socioeconomic', 'data', '.', 'conomic', ',', 'demographic', ',', 'and', 'housing', 'characteristics', '.', 'All', 'three', 'Feature', 'importance', 'analysis', 'identified', 'prior-year', 'homeown-', 'machine', 'learning', 'models', 'evaluated', '—', 'Neural',  ...
#
# Total tokens: 555

# %% [markdown]
# ### 1b. spaCy Tokenisation

# %%
# ── Tokenise with spaCy ───────────────────────────────────────────────────
doc = nlp(ocr_text)

print('=== spaCy TOKENS ===')
for token in doc:
    print(token.text, token.pos_, end=' | ')

print(f'\n\nTotal tokens: {len(doc)}')
print(f'Vocabulary size (en_core_web_sm): {len(doc.vocab)}')
# Out:
# === spaCy TOKENS ===
# someonnersip PROPN | rte PROPN | prev VERB | XGBoost PROPN | Feature PROPN | Importance PROPN | ( PUNCT | Enhanced VERB | with ADP | Historical PROPN | Features PROPN | ) PUNCT | Change NOUN | in ADP | County PROPN | Homeownership PROPN | Rate PROPN | ( PUNCT | 2019 NUM | - SYM | 2022 NUM | ) PUNCT |
#  SPACE | peptone NOUN | ony PROPN | Pec PROPN | Change PROPN | in ADP | Homeownership PROPN |
#  SPACE | ia PROPN | Fig PROPN | . PROPN | 11 NUM | . PUNCT | Evolution NOUN | of ADP | homeownership NOUN |
#  SPACE | Fig PROPN | . PROPN | 10 NUM | . PUNCT | Random PROPN | Forest PROPN | feature NOUN | importance NOUN | as ADP | the DET | most ADV | influential ADJ | factors NOUN | . PUNCT | These DET | results NOUN | highlight VERB | the DET |
#  SPACE | importance NOUN | of ADP | both PRON | historical ADJ | persistence NOUN | and CCONJ | broader ADJ | socioe- ADJ |
#  SPACE | conomic ADJ | conditions NOUN | in ADP | shaping VERB | county NOUN | - PUNCT | level NOUN | homeownership NOUN |
#  SPACE | and CCONJ | decreases VERB | highlights VERB | the DET | heterogeneous ADJ | nature NOUN | of ADP | housing NOUN | patterns NOUN | . PUNCT | In ADP | terms NOUN | of ADP | model NOUN | performance NOUN | , PUNCT | Random PROPN | Forest PROPN |
#  SPACE | market NOUN | dynamics NOUN | , PUNCT | suggesting VERB | that SCONJ | local ADJ | economic ADJ | conditions NOUN | , PUNCT | achieved VERB | the DET | highest ADJ | predictive ADJ | accuracy NOUN | ( PUNCT | R NOUN | ? PUNCT | = SYM | 0.880 NUM | ) PUNCT | , PUNCT |
#  SPACE | demographic ADJ | trends NOUN | , PUNCT | and CCONJ | housing NOUN | supply NOUN | constraints NOUN | likely ADV | followed VERB | closely ADV | by ADP | Gradient PROPN | Boosting PROPN | ( PUNCT | R NOUN | ? PUNCT | = X | 0.8673 NUM | ) PUNCT | and CCONJ |
#  SPACE | contributed VERB | to ADP | differing VERB | outcomes NOUN | across ADP | counties NOUN | . PUNCT | Neural PROPN | Networks PROPN | ( PUNCT | R NOUN | ? PUNCT | = NOUN | 0.770 NUM | ) PUNCT | . PUNCT | These DET | findings NOUN | suggest VERB | that SCONJ |
#  SPACE | ensemble ADJ | tree NOUN | - PUNCT | based VERB | models NOUN | are AUX | particularly ADV | well ADV | - PUNCT | suited VERB | for ADP |
#  SPACE | US PROPN | County PROPN | Homeownership PROPN | Rate PROPN | ( PUNCT | 2022 NUM | ACS PROPN | ) PUNCT | tabular VERB | socioeconomic ADJ | data NOUN | with ADP | nonlinear ADJ | interactions NOUN | , PUNCT | while SCONJ |
#  SPACE | omsounesnpaae ADJ | | NOUN | HUFal PROPN | networks NOUN | can AUX | still ADV | provide VERB | strong ADJ | predictions NOUN | but CCONJ | may AUX |
#  SPACE | be AUX | constrained VERB | by ADP | dataset NOUN | size NOUN | and CCONJ | feature VERB | dimensionality NOUN | . PUNCT |
#  SPACE | * PUNCT | e NOUN | In ADP | general ADJ | , PUNCT | the DET | results NOUN | demonstrate VERB | that SCONJ | integrating VERB | historical ADJ |
#  SPACE | “ PUNCT | features NOUN | into ADP | predictive ADJ | models NOUN | not PART | only ADV | improves VERB | accuracy NOUN | but CCONJ |
#  SPACE | ” PUNCT | fo ADP | also ADV | provides VERB | valuable ADJ | insights NOUN | into ADP | the DET | drivers NOUN | of ADP | county NOUN | - PUNCT | level NOUN |
#  SPACE | , PUNCT | 02 NUM | homeownership NOUN | , PUNCT | offering VERB | practical ADJ | implications NOUN | for ADP | policymak- ADV |
#  SPACE | = PUNCT | ~ PUNCT | : PUNCT | 5 NUM | ers NOUN | and CCONJ | regional ADJ | planners NOUN | interested VERB | in ADP | housing NOUN | stability NOUN | and CCONJ |
#  SPACE | economic ADJ | development NOUN | . PUNCT | However ADV | , PUNCT | several ADJ | limitations NOUN | exist VERB | : PUNCT |
#  SPACE | e NOUN | Only ADV | two NUM | time NOUN | periods NOUN | were AUX | analysed VERB |
#  SPACE | e NOUN | Spatial PROPN | dependencies NOUN | were AUX | not PART | modelled VERB |
#  SPACE | US PROPN | County PROPN | Homeownership PROPN | Rate PROPN | ( PUNCT | 2019 NUM | ACS PROPN | ) PUNCT | e NOUN | ACS PROPN | estimates NOUN | contain VERB | sampling VERB | variability NOUN |
#  SPACE | Homeownership PROPN | Rate PROPN |
#  SPACE | ee PROPN | VIII PROPN | . PUNCT | CONCLUSION PROPN |
#  SPACE | x SYM | se X | This DET | study NOUN | developed VERB | a DET | machine NOUN | learning VERB | framework NOUN | to PART |
#  SPACE | predict VERB | U.S. PROPN | county NOUN | - PUNCT | level NOUN | homeownership NOUN | rates NOUN | using VERB | ACS PROPN |
#  SPACE | . PUNCT | A DET | ws NOUN | , PUNCT | ” PUNCT | data NOUN | . PUNCT | The DET | results NOUN | demonstrate VERB | that SCONJ | county NOUN | - PUNCT | level NOUN | homeownership NOUN |
#  SPACE | ~ PUNCT | ° NUM | ° NOUN | can AUX | be AUX | predicted VERB | with ADP | high ADJ | accuracy NOUN | using VERB | socioeconomic PROPN | , PUNCT | de- PROPN |
#  SPACE | mographic ADJ | , PUNCT | and CCONJ | housing NOUN | characteristics NOUN | . PUNCT | Among ADP | the DET | evaluated ADJ |
#  SPACE | models NOUN | , PUNCT | Random PROPN | Forest PROPN | achieved VERB | the DET | strongest ADJ | performance NOUN |
#  SPACE | Based VERB | on ADP | the DET | results NOUN | of ADP | this DET | study NOUN | , PUNCT | it PRON | is AUX | clear ADJ | that SCONJ | county NOUN | - PUNCT | level NOUN | ( PUNCT | R NOUN | ? PUNCT | = SYM | 0.880 NUM | ) PUNCT | , PUNCT | outperforming VERB | both PRON | neural ADJ | network NOUN | and CCONJ | XG- ADJ |
#  SPACE | homeownership NOUN | rates NOUN | in ADP | the DET | United PROPN | States PROPN | can AUX | be AUX | effectively ADV | Boost NOUN | models NOUN | and CCONJ | highlighting VERB | the DET | effectiveness NOUN | of ADP | ensemble NOUN |
#  SPACE | predicted VERB | using VERB | a DET | combination NOUN | of ADP | current ADJ | and CCONJ | historical ADJ | socioe- NOUN | ee PROPN | methods NOUN | for ADP | structured ADJ | socioeconomic ADJ | data NOUN | . PUNCT |
#  SPACE | conomic PROPN | , PUNCT | demographic ADJ | , PUNCT | and CCONJ | housing NOUN | characteristics NOUN | . PUNCT | All DET | three NUM | Feature NOUN | importance NOUN | analysis NOUN | identified VERB | prior ADJ | - PUNCT | year NOUN | homeown- VERB |
#  SPACE | machine NOUN | learning NOUN | models NOUN | evaluated VERB | — PUNCT | Neural PROPN | Networks PROPN | , PUNCT | Ran- PROPN | ership NOUN | rates NOUN | as ADP | the DET | most ADV | influential ADJ | predictor NOUN | of ADP | homeownership NOUN |
#  SPACE | dom PROPN | Forest PROPN | , PUNCT | and CCONJ | Gradient PROPN | Boosting PROPN | ( PUNCT | XGBoost)—demonstrated VERB | outcomes NOUN | . PUNCT | These DET | findings NOUN | provide VERB | insight NOUN | into ADP | the DET | structural ADJ |
#  SPACE | strong ADJ | predictive ADJ | performance NOUN | , PUNCT | with ADP | R NOUN | ? NOUN | values NOUN | ranging VERB | from ADP | drivers NOUN | of ADP | homeownership NOUN | and CCONJ | offer VERB | actionable ADJ | information NOUN | for ADP |
#  SPACE | 0.770 NUM | to ADP | 0.880 NUM | , PUNCT | indicating VERB | that SCONJ | these DET | features NOUN | capture VERB | sub- NOUN | policymakers NOUN | and CCONJ | housing NOUN | planners NOUN | . PUNCT |
#  SPACE | stantial ADJ | variance NOUN | in ADP | homeownership NOUN | outcomes NOUN | across ADP | counties NOUN | . PUNCT | Future ADJ | research NOUN | could AUX | extend VERB | this DET | work NOUN | by ADP | incorporating VERB |
#  SPACE | Among ADP | the DET | predictor NOUN | variables NOUN | , PUNCT | prior ADJ | - PUNCT | year NOUN | homeownership NOUN | spatial ADJ | econometric ADJ | modelling NOUN | to PART | account VERB | for ADP | geographic ADJ | de- PROPN |
#  SPACE | rates NOUN | , PUNCT | the DET | interaction NOUN | between ADP | poverty NOUN | levels NOUN | and CCONJ | housing NOUN | pendencies NOUN | and CCONJ | by ADP | leveraging VERB | longer ADJ | temporal ADJ | datasets NOUN | to ADP |
#  SPACE | prices NOUN | , PUNCT | population NOUN | density NOUN | , PUNCT | and CCONJ | educational ADJ | attainment PROPN | emerged VERB | better ADJ | capture VERB | dynamic ADJ | housing NOUN | trends NOUN | over ADP | time NOUN | . PUNCT |
#  SPACE |
#
# Total tokens: 615
# Vocabulary size (en_core_web_sm): 1022

# %% [markdown]
# ### 1c. Tokenisation edge cases

# %%
# ── Demonstrate tokenisation on tricky text ───────────────────────────────
# Escaped quotes, abbreviations, apostrophes
sentence = '"Mr. O\'Neill thinks that the boys\' stories about Chile\'s capital aren\'t amusing."'
print('Sentence:', sentence)
print()

nlp_sentence = nlp(sentence)
for token in nlp_sentence:
    print(token.text, token.pos_, end=' | ')

print()
print()

# URLs and times
sentence2 = 'It is best to access our website from 9 a.m. to 1 p.m. every weekend. The address is www.mywebsite.ie.'
doc2 = nlp(sentence2)
print('Sentence:', sentence2)
for token in doc2:
    print(token, end=' | ')
# Out:
# Sentence: "Mr. O'Neill thinks that the boys' stories about Chile's capital aren't amusing."
#
# " PUNCT | Mr. PROPN | O'Neill PROPN | thinks VERB | that SCONJ | the DET | boys NOUN | ' PART | stories NOUN | about ADP | Chile PROPN | 's PART | capital NOUN | are AUX | n't PART | amusing ADJ | . PUNCT | " PUNCT |
#
# Sentence: It is best to access our website from 9 a.m. to 1 p.m. every weekend. The address is www.mywebsite.ie.
# It | is | best | to | access | our | website | from | 9 | a.m. | to | 1 | p.m. | every | weekend | . | The | address | is | www.mywebsite.ie | . |

# %% [markdown]
# ### 1d. Slicing tokens

# %%
# ── Token slicing ─────────────────────────────────────────────────────────
demo = nlp(u'I really like working with words!')

print('All tokens:')
for token in demo:
    print(token)

print('\nFirst token :', demo[0])
print('Last 2 tokens:', demo[-2:])
# Out:
# All tokens:
# I
# really
# like
# working
# with
# words
# !
#
# First token : I
# Last 2 tokens: words!

# %% [markdown]
# ---
# ## 2. Stopword Removal
# ### 2a. NLTK stopwords

# %%
# ── NLTK stopword removal on OCR text ────────────────────────────────────
nltk_stopwords = stopwords.words('english')

tokens_without_sw = [word for word in text_tokens if word not in nltk_stopwords]

print('=== AFTER NLTK STOPWORD REMOVAL ===')
print(tokens_without_sw)
print(f'\nOriginal token count : {len(text_tokens)}')
print(f'After filtering      : {len(tokens_without_sw)}')
print(f'Stopwords removed    : {len(text_tokens) - len(tokens_without_sw)}')
print(f'\nNLTK stopword list size: {len(nltk_stopwords)}')
print(nltk_stopwords)
# Out:
# === AFTER NLTK STOPWORD REMOVAL ===
# ['someonnersip', 'rte', 'prev', 'XGBoost', 'Feature', 'Importance', '(', 'Enhanced', 'Historical', 'Features', ')', 'Change', 'County', 'Homeownership', 'Rate', '(', '2019-2022', ')', 'peptone', 'ony', 'Pec', 'Change', 'Homeownership', 'ia', 'Fig', '.', '11', '.', 'Evolution', 'homeownership', 'Fig', '.', '10', '.', 'Random', 'Forest', 'feature', 'importance', 'influential', 'factors', '.', 'These', 'results', 'highlight', 'importance', 'historical', 'persistence', 'broader', 'socioe-', 'conomic', 'conditions', 'shaping', 'county-level', 'homeownership', 'decreases', 'highlights', 'heterogeneous', 'nature', 'housing', 'patterns', '.', 'In', 'terms', 'model', 'performance', ',', 'Random', 'Forest', 'market', 'dynamics', ',', 'suggesting', 'local', 'economic', 'conditions', ',', 'achieved', 'highest', 'predictive', 'accuracy', '(', 'R', '?', '=', '0.880', ')', ',', 'demographic', 'trends', ',', 'housing', 'supply', 'constraints', 'likely', 'followed', 'closely', 'Gradient', 'Boosting', '(', 'R', '?', '=', '0.8673', ')', 'contributed', 'differing', 'outcomes', 'across', 'counties', '.', 'Neural', 'Networks', '(', 'R', '?', '=', '0.770', ')', '.', 'These', 'findings', 'suggest', 'ensemble', 'tree-based', 'models', 'particularly', 'well-suited', 'US', 'County', 'Homeownership', 'Rate', '(', '2022', 'ACS', ')', 'tabular', 'socioeconomic', 'data', 'nonlinear', 'interactions', ',', 'omsounesnpaae', '|', 'HUFal', 'networks', 'still', 'provide', 'strong', 'predictions', 'may', 'constrained', 'dataset', 'size', 'feature', 'dimensionality', '.', '*', 'e', 'In', 'general', ',', 'results', 'demonstrate', 'integrating', 'historical', '“', 'features', 'predictive', 'models', 'improves', 'accuracy', '”', 'fo', 'also', 'provides', 'valuable', 'insights', 'drivers', 'county-level', ',', '02', 'homeownership', ',', 'offering', 'practical', 'implications', 'policymak-', '=', '~', ':', '5', 'ers', 'regional', 'planners', 'interested', 'housing', 'stability', 'economic', 'development', '.', 'However', ',', 'several', 'limitations', 'exist', ':', 'e', 'Only', 'two', 'time', 'periods', 'analysed', 'e', 'Spatial', 'dependencies', 'modelled', 'US', 'County', 'Homeownership', 'Rate', '(', '2019', 'ACS', ')', 'e', 'ACS', 'estimates', 'contain', 'sampling', 'variability', 'Homeownership', 'Rate', 'ee', 'VIII', '.', 'CONCLUSION', 'x', 'se', 'This', 'study', 'developed', 'machine', 'learning', 'framework', 'predict', 'U.S.', 'county-level', 'homeownership', 'rates', 'using', 'ACS', '.', 'A', 'ws', ',', '”', 'data', '.', 'The', 'results', 'demonstrate', 'county-level', 'homeownership', '~', '°', '°', 'predicted', 'high', 'accuracy', 'using', 'socioeconomic', ',', 'de-', 'mographic', ',', 'housing', 'characteristics', '.', 'Among', 'evaluated', 'models', ',', 'Random', 'Forest', 'achieved', 'strongest', 'performance', 'Based', 'results', 'study', ',', 'clear', 'county-level', '(', 'R', '?', '=', '0.880', ')', ',', 'outperforming', 'neural', 'network', 'XG-', 'homeownership', 'rates', 'United', 'States', 'effectively', 'Boost', 'models', 'highlighting', 'effectiveness', 'ensemble', 'predicted', 'using', 'combination', 'current', 'historical', 'socioe-', 'ee', 'methods', 'structured', 'socioeconomic', 'data', '.', 'conomic', ',', 'demographic', ',', 'housing', 'characteristics', '.', 'All', 'three', 'Feature', 'importance', 'analysis', 'identified', 'prior-year', 'homeown-', 'machine', 'learning', 'models', 'evaluated', '—', 'Neural', 'Networks', ',', 'Ran-', 'ership', 'rates', 'influential', 'predictor', 'homeownership', 'dom', 'Forest', ',', 'Gradient', 'Boosting', '(', 'XGBoost', ')', '—', 'demonstrated', 'outcomes', '.', 'These', 'findings', 'provide', 'insight', 'structural', 'strong', 'predictive', 'performance', ',', 'R', '?', 'values', 'ranging', 'drivers', 'homeownership', 'offer', 'actionable', 'information', '0.770', '0.880', ',', 'indicating', 'features', 'capture', 'sub-', 'policymakers', 'housing', 'planners', '.', 'stantial', 'variance', 'homeowne ...
#
# Original token count : 555
# After filtering      : 447
# Stopwords removed    : 108
#
# NLTK stopword list size: 198
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# ### 2b. Appending and extending the stopword list

# %%
# ── Add a single custom stopword ──────────────────────────────────────────
all_stopwords = stopwords.words('english')
all_stopwords.append('Lorem')

tokens_without_sw = [word for word in text_tokens if word not in all_stopwords]
print('After appending "Lorem":')
print(tokens_without_sw)
print(f'Stopword count: {len(all_stopwords)}')

# ── Extend with a list of custom stopwords ────────────────────────────────
sw_list = ['Ipsum', 'dummy', '2000', 'simply']
all_stopwords.extend(sw_list)

tokens_without_sw = [word for word in text_tokens if word not in all_stopwords]
print('\nAfter extending with list:')
print(tokens_without_sw)
print(f'Stopword count: {len(all_stopwords)}')
# Out:
# After appending "Lorem":
# ['someonnersip', 'rte', 'prev', 'XGBoost', 'Feature', 'Importance', '(', 'Enhanced', 'Historical', 'Features', ')', 'Change', 'County', 'Homeownership', 'Rate', '(', '2019-2022', ')', 'peptone', 'ony', 'Pec', 'Change', 'Homeownership', 'ia', 'Fig', '.', '11', '.', 'Evolution', 'homeownership', 'Fig', '.', '10', '.', 'Random', 'Forest', 'feature', 'importance', 'influential', 'factors', '.', 'These', 'results', 'highlight', 'importance', 'historical', 'persistence', 'broader', 'socioe-', 'conomic', 'conditions', 'shaping', 'county-level', 'homeownership', 'decreases', 'highlights', 'heterogeneous', 'nature', 'housing', 'patterns', '.', 'In', 'terms', 'model', 'performance', ',', 'Random', 'Forest', 'market', 'dynamics', ',', 'suggesting', 'local', 'economic', 'conditions', ',', 'achieved', 'highest', 'predictive', 'accuracy', '(', 'R', '?', '=', '0.880', ')', ',', 'demographic', 'trends', ',', 'housing', 'supply', 'constraints', 'likely', 'followed', 'closely', 'Gradient', 'Boosting', '(', 'R', '?', '=', '0.8673', ')', 'contributed', 'differing', 'outcomes', 'across', 'counties', '.', 'Neural', 'Networks', '(', 'R', '?', '=', '0.770', ')', '.', 'These', 'findings', 'suggest', 'ensemble', 'tree-based', 'models', 'particularly', 'well-suited', 'US', 'County', 'Homeownership', 'Rate', '(', '2022', 'ACS', ')', 'tabular', 'socioeconomic', 'data', 'nonlinear', 'interactions', ',', 'omsounesnpaae', '|', 'HUFal', 'networks', 'still', 'provide', 'strong', 'predictions', 'may', 'constrained', 'dataset', 'size', 'feature', 'dimensionality', '.', '*', 'e', 'In', 'general', ',', 'results', 'demonstrate', 'integrating', 'historical', '“', 'features', 'predictive', 'models', 'improves', 'accuracy', '”', 'fo', 'also', 'provides', 'valuable', 'insights', 'drivers', 'county-level', ',', '02', 'homeownership', ',', 'offering', 'practical', 'implications', 'policymak-', '=', '~', ':', '5', 'ers', 'regional', 'planners', 'interested', 'housing', 'stability', 'economic', 'development', '.', 'However', ',', 'several', 'limitations', 'exist', ':', 'e', 'Only', 'two', 'time', 'periods', 'analysed', 'e', 'Spatial', 'dependencies', 'modelled', 'US', 'County', 'Homeownership', 'Rate', '(', '2019', 'ACS', ')', 'e', 'ACS', 'estimates', 'contain', 'sampling', 'variability', 'Homeownership', 'Rate', 'ee', 'VIII', '.', 'CONCLUSION', 'x', 'se', 'This', 'study', 'developed', 'machine', 'learning', 'framework', 'predict', 'U.S.', 'county-level', 'homeownership', 'rates', 'using', 'ACS', '.', 'A', 'ws', ',', '”', 'data', '.', 'The', 'results', 'demonstrate', 'county-level', 'homeownership', '~', '°', '°', 'predicted', 'high', 'accuracy', 'using', 'socioeconomic', ',', 'de-', 'mographic', ',', 'housing', 'characteristics', '.', 'Among', 'evaluated', 'models', ',', 'Random', 'Forest', 'achieved', 'strongest', 'performance', 'Based', 'results', 'study', ',', 'clear', 'county-level', '(', 'R', '?', '=', '0.880', ')', ',', 'outperforming', 'neural', 'network', 'XG-', 'homeownership', 'rates', 'United', 'States', 'effectively', 'Boost', 'models', 'highlighting', 'effectiveness', 'ensemble', 'predicted', 'using', 'combination', 'current', 'historical', 'socioe-', 'ee', 'methods', 'structured', 'socioeconomic', 'data', '.', 'conomic', ',', 'demographic', ',', 'housing', 'characteristics', '.', 'All', 'three', 'Feature', 'importance', 'analysis', 'identified', 'prior-year', 'homeown-', 'machine', 'learning', 'models', 'evaluated', '—', 'Neural', 'Networks', ',', 'Ran-', 'ership', 'rates', 'influential', 'predictor', 'homeownership', 'dom', 'Forest', ',', 'Gradient', 'Boosting', '(', 'XGBoost', ')', '—', 'demonstrated', 'outcomes', '.', 'These', 'findings', 'provide', 'insight', 'structural', 'strong', 'predictive', 'performance', ',', 'R', '?', 'values', 'ranging', 'drivers', 'homeownership', 'offer', 'actionable', 'information', '0.770', '0.880', ',', 'indicating', 'features', 'capture', 'sub-', 'policymakers', 'housing', 'planners', '.', 'stantial', 'variance', 'homeowne ...
# Stopword count: 199
#
# After extending with list:
# ['someonnersip', 'rte', 'prev', 'XGBoost', 'Feature', 'Importance', '(', 'Enhanced', 'Historical', 'Features', ')', 'Change', 'County', 'Homeownership', 'Rate', '(', '2019-2022', ')', 'peptone', 'ony', 'Pec', 'Change', 'Homeownership', 'ia', 'Fig', '.', '11', '.', 'Evolution', 'homeownership', 'Fig', '.', '10', '.', 'Random', 'Forest', 'feature', 'importance', 'influential', 'factors', '.', 'These', 'results', 'highlight', 'importance', 'historical', 'persistence', 'broader', 'socioe-', 'conomic', 'conditions', 'shaping', 'county-level', 'homeownership', 'decreases', 'highlights', 'heterogeneous', 'nature', 'housing', 'patterns', '.', 'In', 'terms', 'model', 'performance', ',', 'Random', 'Forest', 'market', 'dynamics', ',', 'suggesting', 'local', 'economic', 'conditions', ',', 'achieved', 'highest', 'predictive', 'accuracy', '(', 'R', '?', '=', '0.880', ')', ',', 'demographic', 'trends', ',', 'housing', 'supply', 'constraints', 'likely', 'followed', 'closely', 'Gradient', 'Boosting', '(', 'R', '?', '=', '0.8673', ')', 'contributed', 'differing', 'outcomes', 'across', 'counties', '.', 'Neural', 'Networks', '(', 'R', '?', '=', '0.770', ')', '.', 'These', 'findings', 'suggest', 'ensemble', 'tree-based', 'models', 'particularly', 'well-suited', 'US', 'County', 'Homeownership', 'Rate', '(', '2022', 'ACS', ')', 'tabular', 'socioeconomic', 'data', 'nonlinear', 'interactions', ',', 'omsounesnpaae', '|', 'HUFal', 'networks', 'still', 'provide', 'strong', 'predictions', 'may', 'constrained', 'dataset', 'size', 'feature', 'dimensionality', '.', '*', 'e', 'In', 'general', ',', 'results', 'demonstrate', 'integrating', 'historical', '“', 'features', 'predictive', 'models', 'improves', 'accuracy', '”', 'fo', 'also', 'provides', 'valuable', 'insights', 'drivers', 'county-level', ',', '02', 'homeownership', ',', 'offering', 'practical', 'implications', 'policymak-', '=', '~', ':', '5', 'ers', 'regional', 'planners', 'interested', 'housing', 'stability', 'economic', 'development', '.', 'However', ',', 'several', 'limitations', 'exist', ':', 'e', 'Only', 'two', 'time', 'periods', 'analysed', 'e', 'Spatial', 'dependencies', 'modelled', 'US', 'County', 'Homeownership', 'Rate', '(', '2019', 'ACS', ')', 'e', 'ACS', 'estimates', 'contain', 'sampling', 'variability', 'Homeownership', 'Rate', 'ee', 'VIII', '.', 'CONCLUSION', 'x', 'se', 'This', 'study', 'developed', 'machine', 'learning', 'framework', 'predict', 'U.S.', 'county-level', 'homeownership', 'rates', 'using', 'ACS', '.', 'A', 'ws', ',', '”', 'data', '.', 'The', 'results', 'demonstrate', 'county-level', 'homeownership', '~', '°', '°', 'predicted', 'high', 'accuracy', 'using', 'socioeconomic', ',', 'de-', 'mographic', ',', 'housing', 'characteristics', '.', 'Among', 'evaluated', 'models', ',', 'Random', 'Forest', 'achieved', 'strongest', 'performance', 'Based', 'results', 'study', ',', 'clear', 'county-level', '(', 'R', '?', '=', '0.880', ')', ',', 'outperforming', 'neural', 'network', 'XG-', 'homeownership', 'rates', 'United', 'States', 'effectively', 'Boost', 'models', 'highlighting', 'effectiveness', 'ensemble', 'predicted', 'using', 'combination', 'current', 'historical', 'socioe-', 'ee', 'methods', 'structured', 'socioeconomic', 'data', '.', 'conomic', ',', 'demographic', ',', 'housing', 'characteristics', '.', 'All', 'three', 'Feature', 'importance', 'analysis', 'identified', 'prior-year', 'homeown-', 'machine', 'learning', 'models', 'evaluated', '—', 'Neural', 'Networks', ',', 'Ran-', 'ership', 'rates', 'influential', 'predictor', 'homeownership', 'dom', 'Forest', ',', 'Gradient', 'Boosting', '(', 'XGBoost', ')', '—', 'demonstrated', 'outcomes', '.', 'These', 'findings', 'provide', 'insight', 'structural', 'strong', 'predictive', 'performance', ',', 'R', '?', 'values', 'ranging', 'drivers', 'homeownership', 'offer', 'actionable', 'information', '0.770', '0.880', ',', 'indicating', 'features', 'capture', 'sub-', 'policymakers', 'housing', 'planners', '.', 'stantial', 'variance', 'homeowne ...
# Stopword count: 203

# %% [markdown]
# ### 2c. Removing a stopword

# %%
# ── Remove 'not' so negation is preserved ────────────────────────────────
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')

tokens_without_sw = [word for word in text_tokens if word not in all_stopwords]
print('After removing "not" from stopwords:')
print(tokens_without_sw)
# Out:
# After removing "not" from stopwords:
# ['someonnersip', 'rte', 'prev', 'XGBoost', 'Feature', 'Importance', '(', 'Enhanced', 'Historical', 'Features', ')', 'Change', 'County', 'Homeownership', 'Rate', '(', '2019-2022', ')', 'peptone', 'ony', 'Pec', 'Change', 'Homeownership', 'ia', 'Fig', '.', '11', '.', 'Evolution', 'homeownership', 'Fig', '.', '10', '.', 'Random', 'Forest', 'feature', 'importance', 'influential', 'factors', '.', 'These', 'results', 'highlight', 'importance', 'historical', 'persistence', 'broader', 'socioe-', 'conomic', 'conditions', 'shaping', 'county-level', 'homeownership', 'decreases', 'highlights', 'heterogeneous', 'nature', 'housing', 'patterns', '.', 'In', 'terms', 'model', 'performance', ',', 'Random', 'Forest', 'market', 'dynamics', ',', 'suggesting', 'local', 'economic', 'conditions', ',', 'achieved', 'highest', 'predictive', 'accuracy', '(', 'R', '?', '=', '0.880', ')', ',', 'demographic', 'trends', ',', 'housing', 'supply', 'constraints', 'likely', 'followed', 'closely', 'Gradient', 'Boosting', '(', 'R', '?', '=', '0.8673', ')', 'contributed', 'differing', 'outcomes', 'across', 'counties', '.', 'Neural', 'Networks', '(', 'R', '?', '=', '0.770', ')', '.', 'These', 'findings', 'suggest', 'ensemble', 'tree-based', 'models', 'particularly', 'well-suited', 'US', 'County', 'Homeownership', 'Rate', '(', '2022', 'ACS', ')', 'tabular', 'socioeconomic', 'data', 'nonlinear', 'interactions', ',', 'omsounesnpaae', '|', 'HUFal', 'networks', 'still', 'provide', 'strong', 'predictions', 'may', 'constrained', 'dataset', 'size', 'feature', 'dimensionality', '.', '*', 'e', 'In', 'general', ',', 'results', 'demonstrate', 'integrating', 'historical', '“', 'features', 'predictive', 'models', 'not', 'improves', 'accuracy', '”', 'fo', 'also', 'provides', 'valuable', 'insights', 'drivers', 'county-level', ',', '02', 'homeownership', ',', 'offering', 'practical', 'implications', 'policymak-', '=', '~', ':', '5', 'ers', 'regional', 'planners', 'interested', 'housing', 'stability', 'economic', 'development', '.', 'However', ',', 'several', 'limitations', 'exist', ':', 'e', 'Only', 'two', 'time', 'periods', 'analysed', 'e', 'Spatial', 'dependencies', 'not', 'modelled', 'US', 'County', 'Homeownership', 'Rate', '(', '2019', 'ACS', ')', 'e', 'ACS', 'estimates', 'contain', 'sampling', 'variability', 'Homeownership', 'Rate', 'ee', 'VIII', '.', 'CONCLUSION', 'x', 'se', 'This', 'study', 'developed', 'machine', 'learning', 'framework', 'predict', 'U.S.', 'county-level', 'homeownership', 'rates', 'using', 'ACS', '.', 'A', 'ws', ',', '”', 'data', '.', 'The', 'results', 'demonstrate', 'county-level', 'homeownership', '~', '°', '°', 'predicted', 'high', 'accuracy', 'using', 'socioeconomic', ',', 'de-', 'mographic', ',', 'housing', 'characteristics', '.', 'Among', 'evaluated', 'models', ',', 'Random', 'Forest', 'achieved', 'strongest', 'performance', 'Based', 'results', 'study', ',', 'clear', 'county-level', '(', 'R', '?', '=', '0.880', ')', ',', 'outperforming', 'neural', 'network', 'XG-', 'homeownership', 'rates', 'United', 'States', 'effectively', 'Boost', 'models', 'highlighting', 'effectiveness', 'ensemble', 'predicted', 'using', 'combination', 'current', 'historical', 'socioe-', 'ee', 'methods', 'structured', 'socioeconomic', 'data', '.', 'conomic', ',', 'demographic', ',', 'housing', 'characteristics', '.', 'All', 'three', 'Feature', 'importance', 'analysis', 'identified', 'prior-year', 'homeown-', 'machine', 'learning', 'models', 'evaluated', '—', 'Neural', 'Networks', ',', 'Ran-', 'ership', 'rates', 'influential', 'predictor', 'homeownership', 'dom', 'Forest', ',', 'Gradient', 'Boosting', '(', 'XGBoost', ')', '—', 'demonstrated', 'outcomes', '.', 'These', 'findings', 'provide', 'insight', 'structural', 'strong', 'predictive', 'performance', ',', 'R', '?', 'values', 'ranging', 'drivers', 'homeownership', 'offer', 'actionable', 'information', '0.770', '0.880', ',', 'indicating', 'features', 'capture', 'sub-', 'policymakers', 'housing', 'planners', '.', 'stantial', 'varian ...

# %% [markdown]
# ### 2d. spaCy stopword removal

# %%
# ── spaCy stopword list ───────────────────────────────────────────────────
sp_stopwords = nlp.Defaults.stop_words

text_kevin = 'Kevin likes to write code in Java, however he is not too fond of C++.'
kevin_tokens = word_tokenize(text_kevin)

tokens_without_sw = [word for word in kevin_tokens if word not in sp_stopwords]
print('spaCy — stopwords removed:')
print(tokens_without_sw)
print(f'\nspaCy stopword list size: {len(sp_stopwords)}')

# ── Add a custom token to spaCy stopwords ────────────────────────────────
sp_stopwords.add('C++')
tokens_without_sw = [word for word in kevin_tokens if word not in sp_stopwords]
print('\nAfter adding "C++" to spaCy stopwords:')
print(tokens_without_sw)

# ── Remove 'not' from spaCy stopwords ────────────────────────────────────
sp_stopwords = nlp.Defaults.stop_words
sp_stopwords.remove('not')
tokens_without_sw = [word for word in kevin_tokens if word not in sp_stopwords]
print('\nAfter removing "not" from spaCy stopwords:')
print(tokens_without_sw)
# Out:
# spaCy — stopwords removed:
# ['Kevin', 'likes', 'write', 'code', 'Java', ',', 'not', 'fond', '.']
#
# spaCy stopword list size: 326
#
# After adding "C++" to spaCy stopwords:
# ['Kevin', 'likes', 'write', 'code', 'Java', ',', 'not', 'fond', '.']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 20
#      16 print(tokens_without_sw)
#      17
#      18 # ── Remove 'not' from spaCy stopwords ────────────────────────────────────
#      19 sp_stopwords = nlp.Defaults.stop_words
# ---> 20 sp_stopwords.remove('not')
#      21 tokens_without_sw = [word for word in kevin_tokens if word not in sp_stopwords]
#      22 print('\nAfter removing "not" from spaCy stopwords:')
#      23 print(tokens_without_sw)
#
# KeyError: 'not'

# %% [markdown]
# ### 2e. spaCy stopword removal from OCR text

# %%
# ── Apply spaCy stopword removal to OCR text ──────────────────────────────
doc = nlp(ocr_text)

filtered_tokens = [
    token.text
    for token in doc
    if not token.is_stop
    and not token.is_punct
    and not token.is_space
]
clean_text = ' '.join(filtered_tokens)

print('=== CLEANED TEXT (spaCy — stopwords + punctuation removed) ===')
print(clean_text)

total_count    = len([t for t in doc if not t.is_punct and not t.is_space])
filtered_count = len(filtered_tokens)
stopword_count = total_count - filtered_count

print(f'\nTotal tokens (with stopwords) : {total_count}')
print(f'Tokens (without stopwords)    : {filtered_count}')
print(f'Stopwords removed             : {stopword_count}')
# Out:
# === CLEANED TEXT (spaCy — stopwords + punctuation removed) ===
# someonnersip rte prev XGBoost Feature Importance Enhanced Historical Features Change County Homeownership Rate 2019 2022 peptone ony Pec Change Homeownership ia Fig 11 Evolution homeownership Fig 10 Random Forest feature importance influential factors results highlight importance historical persistence broader socioe- conomic conditions shaping county level homeownership decreases highlights heterogeneous nature housing patterns terms model performance Random Forest market dynamics suggesting local economic conditions achieved highest predictive accuracy R = 0.880 demographic trends housing supply constraints likely followed closely Gradient Boosting R = 0.8673 contributed differing outcomes counties Neural Networks R = 0.770 findings suggest ensemble tree based models particularly suited County Homeownership Rate 2022 ACS tabular socioeconomic data nonlinear interactions omsounesnpaae | HUFal networks provide strong predictions constrained dataset size feature dimensionality e general results demonstrate integrating historical features predictive models not improves accuracy fo provides valuable insights drivers county level 02 homeownership offering practical implications policymak- = ~ 5 ers regional planners interested housing stability economic development limitations exist e time periods analysed e Spatial dependencies not modelled County Homeownership Rate 2019 ACS e ACS estimates contain sampling variability Homeownership Rate ee VIII CONCLUSION x se study developed machine learning framework predict U.S. county level homeownership rates ACS ws data results demonstrate county level homeownership ~ ° ° predicted high accuracy socioeconomic de- mographic housing characteristics evaluated models Random Forest achieved strongest performance Based results study clear county level R = 0.880 outperforming neural network XG- homeownership rates United States effectively Boost models highlighting effectiveness ensemble predicted combination current historical socioe- ee methods structured socioeconomic data conomic demographic housing characteristics Feature importance analysis identified prior year homeown- machine learning models evaluated Neural Networks Ran- ership rates influential predictor homeownership dom Forest Gradient Boosting XGBoost)—demonstrated outcomes findings provide insight structural strong predictive performance R values ranging drivers homeownership offer actionable information 0.770 0.880 indicating features capture sub- policymakers housing planners stantial variance homeownership outcomes counties Future research extend work incorporating predictor variables prior year homeownership spatial econometric modelling account geographic de- rates interaction poverty levels housing pendencies leveraging longer temporal datasets prices population density educational attainment emerged better capture dynamic housing trends time
#
# Total tokens (with stopwords) : 487
# Tokens (without stopwords)    : 353
# Stopwords removed             : 134

# %% [markdown]
# ---
# ## 3. Lemmatisation
# ### 3a. spaCy lemmatisation (context-aware)

# %%
# ── Lemmatise using spaCy ─────────────────────────────────────────────────
doc = nlp(ocr_text)

lemmatised = [
    token.lemma_.lower()
    for token in doc
    if not token.is_stop
    and not token.is_punct
    and not token.is_space
]

print('=== LEMMATISED TOKENS ===')
print(' | '.join(lemmatised))
# Out:
# === LEMMATISED TOKENS ===
# someonnersip | rte | prev | xgboost | feature | importance | enhance | historical | features | change | county | homeownership | rate | 2019 | 2022 | peptone | ony | pec | change | homeownership | ia | fig | 11 | evolution | homeownership | fig | 10 | random | forest | feature | importance | influential | factor | result | highlight | importance | historical | persistence | broad | socioe- | conomic | condition | shape | county | level | homeownership | decrease | highlight | heterogeneous | nature | housing | pattern | term | model | performance | random | forest | market | dynamic | suggest | local | economic | condition | achieve | high | predictive | accuracy | r | = | 0.880 | demographic | trend | housing | supply | constraint | likely | follow | closely | gradient | boosting | r | = | 0.8673 | contribute | differ | outcome | county | neural | networks | r | = | 0.770 | finding | suggest | ensemble | tree | base | model | particularly | suit | county | homeownership | rate | 2022 | acs | tabular | socioeconomic | datum | nonlinear | interaction | omsounesnpaae | | | hufal | network | provide | strong | prediction | constrain | dataset | size | feature | dimensionality | e | general | result | demonstrate | integrate | historical | feature | predictive | model | not | improve | accuracy | fo | provide | valuable | insight | driver | county | level | 02 | homeownership | offer | practical | implication | policymak- | = | ~ | 5 | er | regional | planner | interest | housing | stability | economic | development | limitation | exist | e | time | period | analyse | e | spatial | dependency | not | model | county | homeownership | rate | 2019 | acs | e | acs | estimate | contain | sample | variability | homeownership | rate | ee | viii | conclusion | x | se | study | develop | machine | learn | framework | predict | u.s. | county | level | homeownership | rate | acs | ws | datum | result | demonstrate | county | level | homeownership | ~ | ° | ° | predict | high | accuracy | socioeconomic | de- | mographic | housing | characteristic | evaluated | model | random | forest | achieve | strong | performance | base | result | study | clear | county | level | r | = | 0.880 | outperform | neural | network | xg- | homeownership | rate | united | states | effectively | boost | model | highlight | effectiveness | ensemble | predict | combination | current | historical | socioe- | ee | method | structured | socioeconomic | datum | conomic | demographic | housing | characteristic | feature | importance | analysis | identify | prior | year | homeown- | machine | learning | model | evaluate | neural | networks | ran- | ership | rate | influential | predictor | homeownership | dom | forest | gradient | boosting | xgboost)—demonstrate | outcome | finding | provide | insight | structural | strong | predictive | performance | r | value | range | driver | homeownership | offer | actionable | information | 0.770 | 0.880 | indicate | feature | capture | sub- | policymaker | housing | planner | stantial | variance | homeownership | outcome | county | future | research | extend | work | incorporate | predictor | variable | prior | year | homeownership | spatial | econometric | modelling | account | geographic | de- | rate | interaction | poverty | level | housing | pendencie | leverage | long | temporal | dataset | price | population | density | educational | attainment | emerge | well | capture | dynamic | housing | trend | time

# %% [markdown]
# ### 3b. Filtered vs lemmatised — side-by-side

# %%
# ── Compare filtered tokens vs their lemmas ───────────────────────────────
filtered = [
    token.text.lower()
    for token in doc
    if not token.is_stop and not token.is_punct and not token.is_space
]

print(f'{"Original":<25} {"Lemmatised (spaCy)":<25}')
print('-' * 50)
for orig, lemma in zip(filtered, lemmatised):
    print(f'{orig:<25} {lemma:<25}')
# Out:
# Original                  Lemmatised (spaCy)
# --------------------------------------------------
# someonnersip              someonnersip
# rte                       rte
# prev                      prev
# xgboost                   xgboost
# feature                   feature
# importance                importance
# enhanced                  enhance
# historical                historical
# features                  features
# change                    change
# county                    county
# homeownership             homeownership
# rate                      rate
# 2019                      2019
# 2022                      2022
# peptone                   peptone
# ony                       ony
# pec                       pec
# change                    change
# homeownership             homeownership
# ia                        ia
# fig                       fig
# 11                        11
# evolution                 evolution
# homeownership             homeownership
# fig                       fig
# 10                        10
# random                    random
# forest                    forest
# feature                   feature
# importance                importance
# influential               influential
# factors                   factor
# results                   result
# highlight                 highlight
# importance                importance
# historical                historical
# persistence               persistence
# broader                   broad
# socioe-                   socioe-
# conomic                   conomic
# conditions                condition
# shaping                   shape
# county                    county
# level                     level
# homeownership             homeownership
# decreases                 decrease
# highlights                highlight
# heterogeneous             heterogeneous
# nature                    nature
# housing                   housing
# patterns                  pattern
# terms                     term
# model                     model
# performance               performance
# random                    random
# forest                    forest
# market                    market
# dynamics                  dynamic
# suggesting                suggest
# local                     local
# economic                  economic
# conditions                condition
# achieved                  achieve
# highest                   high
# predictive                predictive
# accuracy                  accuracy
# r                         r
# =                         =
# 0.880                     0.880
# demographic               demographic
# trends                    trend
# housing                   housing
# supply                    supply
# constraints               constraint
# likely                    likely
# followed                  follow
# closely                   closely
# gradient                  gradient
# boosting                  boosting
# r                         r
# =                         =
# 0.8673                    0.8673
# contributed               contribute
# differing                 differ
# outcomes                  outcome
# counties                  county
# neural                    neural
# networks                  networks
# r                         r
# =                         =
# 0.770                     0.770
# findings                  finding
# suggest                   suggest
# ensemble                  ensemble
# tree                      tree
# based                     base
# models                    model
# particularly              particularly
# suited                    suit
# county                    county
# homeownership             homeownership
# rate                      rate
# 2022                      2022
# acs                       acs
# tabular                   tabular
# socioeconomic             socioeconomic
# data                      datum
# nonlinear                 nonlinear
# interactions              interaction
# omsounesnpaae             omsounesnpaae
# |                         |
# hufal                     hufal
# networks                  network
# provide                   provide
# strong                    strong
# predictions               prediction
# constrained               constrain
# dataset                   dataset
# size                      size
# feature                   feature
# dimensionality            dimensionality
# e                         e
# general                   general
# results                   result
# demonstrate               demonstrate
# integrating               integrate
# historical                historical
# features                  feature
# predictive                predictive
# models                    model
# not                       not
# improves                  improve
# accuracy                  accuracy
# fo                        fo
# provides                  provide
# valuable                  valuable
# insights                  insight
# drivers                   driver
# county                    county
# level                     level
# 02                        02
# homeownership             homeownership
# offering                  offer
# practical                 practical
# implications              implication
# policymak-                policymak-
# =                         =
# ~                         ~
# 5                         5
# ers                       er
# regional                  regional
# planners                  planner
# interested                interest
# housing                   housing
# stability                 stability
# economic                  economic
# development               development
# limitations               limitation
# exist                     exist
# e                         e
# time                      time
# periods                   period
# analysed                  analyse
# e                         e
# spatial                   spatial
# dependencies              dependency
# not                       not
# modelled                  model
# county                    county
# homeownership             homeownership
# rate                      rate
# 2019                      2019
# acs                       acs
# e                         e
# acs                       acs
# estimates                 estimate
# contain                   contain
# sampling                  sample
# variability               variability
# homeownership             homeownership
# rate                      rate
# ee                        ee
# viii                      viii
# conclusion                conclusion
# x                         x
# se                        se
# study                     study
# developed                 develop
# machine                   machine
# learning                  learn
# framework                 framework
# predict                   predict
# u.s.                      u.s.
# county                    county
# level                     level
# homeownership             homeownership
# rates                     rate
# acs                       acs
# ws                        ws
# data                      datum
# results                   result
# demonstrate               demonstrate
# county                    county
# level                     level
# homeownership             homeownership
# ~                         ~
# °                         °
# °                         °
# predicted                 predict
# high                      high
# accuracy                  accuracy
# socioeconomic             socioeconomic
# de-                       de-
# mographic                 mographic
# housing                   housing
# characteristics           characteristic
# evaluated                 evaluated
# models                    model
# random                    random
# forest                    forest
# achieved                  achieve
# strongest                 strong
# performance               performance
# based                     base
# results                   result
# study                     study
# clear                     clear
# county                    county
# level                     level
# r                         r
# =                         =
# 0.880                     0.880
# outperforming             outperform
# neural                    neural
# network                   network
# xg-                       xg-
# homeownership             homeownership
# rates                     rate
# united                    united
# states                    states
# effectively               effectively
# boost                     boost
# models                    model
# highlighting              highlight
# effectiveness             effectiveness
# ensemble                  ensemble
# predicted                 predict
# combination               combination
# current                   current
# historical                historical
# socioe-                   socioe-
# ee                        ee
# methods                   method
# structured                structured
# socioeconomic             socioeconomic
# data                      datum
# conomic                   conomic
# demographic               demographic
# housing                   housing
# characteristics           characteristic
# feature                   feature
# importance                importance
# analysis                  analysis
# identified                identify
# prior                     prior
# year                      year
# homeown-                  homeown-
# machine                   machine
# learning                  learning
# models                    model
# evaluated                 evaluate
# neural                    neural
# networks                  networks
# ran-                      ran-
# ership                    ership
# rates                     rate
# influential               influential
# predictor                 predictor
# homeownership             homeownership
# dom                       dom
# forest                    forest
# gradient                  gradient
# boosting                  boosting
# xgboost)—demonstrated     xgboost)—demonstrate
# outcomes                  outcome
# findings                  finding
# provide                   provide
# insight                   insight
# structural                structural
# strong                    strong
# predictive                predictive
# performance               performance
# r                         r
# values                    value
# ranging                   range
# drivers                   driver
# homeownership             homeownership
# offer                     offer
# actionable                actionable
# information               information
# 0.770                     0.770
# 0.880                     0.880
# indicating                indicate
# features                  feature
# capture                   capture
# sub-                      sub-
# policymakers              policymaker
# housing                   housing
# planners                  planner
# stantial                  stantial
# variance                  variance
# homeownership             homeownership
# outcomes                  outcome
# counties                  county
# future                    future
# research                  research
# extend                    extend
# work                      work
# incorporating             incorporate
# predictor                 predictor
# variables                 variable
# prior                     prior
# year                      year
# homeownership             homeownership
# spatial                   spatial
# econometric               econometric
# modelling                 modelling
# account                   account
# geographic                geographic
# de-                       de-
# rates                     rate
# interaction               interaction
# poverty                   poverty
# levels                    level
# housing                   housing
# pendencies                pendencie
# leveraging                leverage
# longer                    long
# temporal                  temporal
# datasets                  dataset
# prices                    price
# population                population
# density                   density
# educational               educational
# attainment                attainment
# emerged                   emerge
# better                    well
# capture                   capture
# dynamic                   dynamic
# housing                   housing
# trends                    trend
# time                      time

# %% [markdown]
# ---
# ## 4. Named Entity Recognition (NER)
# ### 4a. Entity extraction using spaCy

# %%
# ── NER on a sample sentence ──────────────────────────────────────────────
doc_object = nlp(u'Samsung in Ireland are pleased with their new folding screen '
                 u'that they released after a large $9 million investment.')

# Basic entity print
print('=== ENTITIES ===')
for entity in doc_object.ents:
    print(entity)

print()

# Entity + label
print('=== ENTITY + LABEL ===')
for entity in doc_object.ents:
    print(entity, entity.label_)

print()

# Entity + label + description
print('=== ENTITY + LABEL + DESCRIPTION ===')
for entity in doc_object.ents:
    print(entity, entity.label_, spacy.explain(entity.label_))
# Out:
# === ENTITIES ===
# Samsung
# Ireland
# a large
# $9 million
#
# === ENTITY + LABEL ===
# Samsung ORG
# Ireland GPE
# a large MONEY
# $9 million MONEY
#
# === ENTITY + LABEL + DESCRIPTION ===
# Samsung ORG Companies, agencies, institutions, etc.
# Ireland GPE Countries, cities, states
# a large MONEY Monetary values, including unit
# $9 million MONEY Monetary values, including unit

# %%
# ── show_entity_info helper function ─────────────────────────────────────
def show_entity_info(doc_object):
    """Print entity text, label and description in a table."""
    if doc_object.ents:
        header = f'{"Entity":<30} {"Label":<20} {"Description"}'
        print(header)
        print('-' * 70)
        for entity in doc_object.ents:
            print(f'{entity.text:<30} {entity.label_:<20} {spacy.explain(entity.label_)}')
    else:
        print('No entities found in text.')

# ── Apply to the OCR text ─────────────────────────────────────────────────
print('=== NER — OCR TEXT ===')
show_entity_info(nlp(ocr_text))
# Out:
# === NER — OCR TEXT ===
# Entity                         Label                Description
# ----------------------------------------------------------------------
# XGBoost Feature Importance (Enhanced with Historical Features ORG                  Companies, agencies, institutions, etc.
# County Homeownership Rate      ORG                  Companies, agencies, institutions, etc.
# 2019-2022                      DATE                 Absolute or relative dates or periods
# Fig                            PERSON               People, including fictional
# Fig                            PERSON               People, including fictional
# 10                             CARDINAL             Numerals that do not fall under another type
# Random Forest                  ORG                  Companies, agencies, institutions, etc.
# Random Forest                  ORG                  Companies, agencies, institutions, etc.
# 0.880                          CARDINAL             Numerals that do not fall under another type
# Gradient Boosting              PERSON               People, including fictional
# 0.8673                         CARDINAL             Numerals that do not fall under another type
# Neural Networks                ORG                  Companies, agencies, institutions, etc.
# 0.770                          CARDINAL             Numerals that do not fall under another type
# US County Homeownership Rate   ORG                  Companies, agencies, institutions, etc.
# 2022                           DATE                 Absolute or relative dates or periods
# HUFal                          ORG                  Companies, agencies, institutions, etc.
# 02                             CARDINAL             Numerals that do not fall under another type
# 5                              CARDINAL             Numerals that do not fall under another type
# Only two                       CARDINAL             Numerals that do not fall under another type
# US County Homeownership Rate   ORG                  Companies, agencies, institutions, etc.
# 2019                           DATE                 Absolute or relative dates or periods
# ACS                            ORG                  Companies, agencies, institutions, etc.
# Homeownership Rate             ORG                  Companies, agencies, institutions, etc.
# U.S.                           GPE                  Countries, cities, states
# ACS                            ORG                  Companies, agencies, institutions, etc.
# Random Forest                  ORG                  Companies, agencies, institutions, etc.
# 0.880                          CARDINAL             Numerals that do not fall under another type
# XG-                            NORP                 Nationalities or religious or political groups
# the United States              GPE                  Countries, cities, states
# Boost                          PERSON               People, including fictional
# three                          CARDINAL             Numerals that do not fall under another type
# prior-year                     DATE                 Absolute or relative dates or periods
# Neural Networks                ORG                  Companies, agencies, institutions, etc.
# Gradient Boosting              PERSON               People, including fictional
# 0.770                          CARDINAL             Numerals that do not fall under another type
# 0.880                          CARDINAL             Numerals that do not fall under another type
# prior-year                     DATE                 Absolute or relative dates or periods

# %% [markdown]
# ### 4b. NER visualisation with displaCy

# %%
# ── Render NER with displaCy ──────────────────────────────────────────────
doc_object = nlp(ocr_text)

html = displacy.render(doc_object, style='ent', jupyter=False)
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">someonnersip rte prev
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XGBoost Feature Importance (Enhanced with Historical Features
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) Change in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     County Homeownership Rate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019-2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# )<br>peptone ony Pec Change in Homeownership<br>ia
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . 11. Evolution of homeownership<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Random Forest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  feature importance as the most influential factors. These results highlight the<br>importance of both historical persistence and broader socioe-<br>conomic conditions in shaping county-level homeownership<br>and decreases highlights the heterogeneous nature of housing patterns. In terms of model performance,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Random Forest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>market dynamics, suggesting that local economic conditions, achieved the highest predictive accuracy (R? =
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.880
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ),<br>demographic trends, and housing supply constraints likely followed closely by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gradient Boosting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (R? =
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.8673
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) and<br>contributed to differing outcomes across counties.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Neural Networks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (R? =
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.770
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ). These findings suggest that<br>ensemble tree-based models are particularly well-suited for<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US County Homeownership Rate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ACS) tabular socioeconomic data with nonlinear interactions, while<br>omsounesnpaae |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HUFal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  networks can still provide strong predictions but may<br>be constrained by dataset size and feature dimensionality.<br>* e In general, the results demonstrate that integrating historical<br>“ features into predictive models not only improves accuracy but<br>” fo also provides valuable insights into the drivers of county-level<br>,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     02
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  homeownership, offering practical implications for policymak-<br>= ~ :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ers and regional planners interested in housing stability and<br>economic development. However, several limitations exist:<br>e
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Only two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  time periods were analysed<br>e Spatial dependencies were not modelled<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US County Homeownership Rate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: mid

# %% [markdown]
# ---
# ## 5. Key Phrases — Noun Chunks
# ### 5a. Extracting noun chunks

# %%
# ── Noun chunk extraction ─────────────────────────────────────────────────
doc_object = nlp(u'Autonomous cars shift insurance liability toward manufacturers')

column1 = 'Text'
column2 = 'Root text'
column3 = 'Root dependency'
column4 = 'Root head text'

print(f'{column1:25} {column2:20} {column3:25} {column4:20}')

for chunk in doc_object.noun_chunks:
    print(f'{chunk.text:{25}} {chunk.root.text:{20}} '
          f'{spacy.explain(chunk.root.dep_):{25}} {chunk.root.head.text:{20}}')
# Out:
# Text                      Root text            Root dependency           Root head text
# Autonomous cars           cars                 nominal subject           shift
# insurance liability       liability            direct object             shift
# manufacturers             manufacturers        object of preposition     toward

# %% [markdown]
# ### 5b. Noun chunks from OCR text

# %%
# ── Key phrases from the OCR document ────────────────────────────────────
doc_ocr = nlp(ocr_text)

print(f'{"Phrase":<35} {"Root":<18} {"Dependency":<28} {"Head"}')
print('-' * 90)

for chunk in doc_ocr.noun_chunks:
    print(f'{chunk.text:<35} {chunk.root.text:<18} '
          f'{str(spacy.explain(chunk.root.dep_)):<28} {chunk.root.head.text}')
# Out:
# Phrase                              Root               Dependency                   Head
# ------------------------------------------------------------------------------------------
# someonnersip rte                    rte                nominal subject              prev
# XGBoost Feature Importance          Importance         direct object                prev
# Historical Features                 Features           object of preposition        with
# Change                              Change             direct object                prev
# County Homeownership Rate           Rate               object of preposition        in
# peptone ony Pec Change              Change             root                         Change
# Homeownership                       Homeownership      object of preposition        in
# ia Fig                              Fig                appositional modifier        Homeownership
# Evolution                           Evolution          root                         Evolution
# homeownership
# Fig                   Fig                object of preposition        of
# Random Forest feature importance    importance         root                         importance
# the most influential factors        factors            object of preposition        as
# These results                       results            nominal subject              highlight
# the
# importance                      importance         nominal subject              highlights
# both historical persistence         persistence        object of preposition        of
# broader socioe-
# conomic conditions  conditions         conjunct                     persistence
# county-level homeownership          homeownership      direct object                shaping
# the heterogeneous nature            nature             direct object                highlights
# housing patterns                    patterns           object of preposition        of
# terms                               terms              object of preposition        In
# model performance                   performance        object of preposition        of
# local economic conditions           conditions         nominal subject              achieved
# the highest predictive accuracy     accuracy           direct object                achieved
# (R                                  R                  appositional modifier        accuracy
# demographic trends                  trends             conjunct                     accuracy
# housing supply constraints          constraints        nominal subject              followed
# Gradient Boosting                   Boosting           object of preposition        by
# R                                   R                  appositional modifier        Boosting
# outcomes                            outcomes           direct object                differing
# counties                            counties           object of preposition        across
# Neural Networks                     Networks           root                         Networks
# (R                                  R                  appositional modifier        Networks
# =                                   =                  appositional modifier        Networks
# These findings                      findings           nominal subject              suggest
# ensemble tree-based models          models             nominal subject              are
# US County Homeownership Rate        Rate               object of preposition        for
# 2022 ACS                            ACS                appositional modifier        Rate
# socioeconomic data                  data               direct object                tabular
# nonlinear interactions              interactions       object of preposition        with
# omsounesnpaae | HUFal networks      networks           nominal subject              provide
# strong predictions                  predictions        direct object                provide
# dataset size                        size               object of preposition        by
# dimensionality                      dimensionality     direct object                feature
# * e                                 e                  nominal subject              demonstrate
# the results                         results            nominal subject              demonstrate
# historical
# “ features               features           direct object                integrating
# predictive models                   models             object of preposition        into
# accuracy                            accuracy           direct object                improves
# valuable insights                   insights           direct object                provides
# the drivers                         drivers            object of preposition        into
# county-level                        level              object of preposition        of
# 02 homeownership                    homeownership      conjunct                     drivers
# practical implications              implications       direct object                offering
# 5 ers                               ers                appositional modifier        improves
# regional planners                   planners           conjunct                     ers
# housing stability                   stability          object of preposition        in
# economic development                development        conjunct                     stability
# several limitations                 limitations        nominal subject              exist
# e                                   e                  appositional modifier        exist
# Only two time periods               periods            nominal subject (passive)    analysed
# e                                   e                  direct object                analysed
# Spatial dependencies                dependencies       nominal subject (passive)    modelled
# US County Homeownership Rate        Rate               object predicate             modelled
# 2019 ACS                            ACS                appositional modifier        Rate
# e ACS estimates                     estimates          nominal subject              contain
# variability
# Homeownership Rate      Rate               direct object                sampling
# VIII                                VIII               appositional modifier        Rate
# CONCLUSION                          CONCLUSION         nominal subject              developed
# This study                          study              nominal subject              developed
# a machine learning framework        framework          direct object                developed
# U.S. county-level homeownership rates rates              direct object                predict
# ACS                                 ACS                direct object                using
# A ws, ” data                        data               root                         data
# The results                         results            nominal subject              demonstrate
# that county-level homeownership     homeownership      direct object                demonstrate
# °                                   °                  nominal subject (passive)    predicted
# high accuracy                       accuracy           object of preposition        with
# housing characteristics             characteristics    conjunct                     mographic
# the evaluated
# models                models             object of preposition        Among
# Random Forest                       Forest             nominal subject              achieved
# the strongest performance           performance        direct object                achieved
# the results                         results            object of preposition        on
# this study                          study              object of preposition        of
# it                                  it                 nominal subject              is
# both neural network                 network            nominal subject              be
# XG-
# homeownership rates             rates              conjunct                     network
# the United States                   States             object of preposition        in
# effectively Boost models            models             attribute                    be
# the effectiveness                   effectiveness      direct object                highlighting
# ensemble                            ensemble           object of preposition        of
# a combination                       combination        direct object                using
# current and historical socioe- ee methods methods            object of preposition        of
# structured socioeconomic data       data               object of preposition        for
# conomic, demographic, and housing characteristics characteristics    root                         characteristics
# All three Feature importance analysis analysis           nominal subject              identified
# prior-year homeown-
# machine learning models models             nominal subject              evaluated
# Neural Networks                     Networks           appositional modifier        models
# Ran- ership rates                   rates              conjunct                     Networks
# the most influential predictor      predictor          object of preposition        as
# homeownership
# dom Forest            Forest             object of preposition        of
# Gradient Boosting                   Boosting           conjunct                     rates
# XGBoost)—demonstrated outcomes      outcomes           appositional modifier        Boosting
# These findings                      findings           nominal subject              provide
# insight                             insight            direct object                provide
# the structural
# strong predictive performance performance        object of preposition        into
# R? values                           values             object of preposition        with
# drivers                             drivers            object of preposition        from
# homeownership                       homeownership      object of preposition        of
# actionable information              information        direct object                offer
# these features                      features           nominal subject              capture
# sub- policymakers                   policymakers       direct object                capture
# housing planners                    planners           conjunct                     policymakers
# stantial variance                   variance           root                         variance
# homeownership outcomes              outcomes           object of preposition        in
# counties                            counties           object of preposition        across
# Future research                     research           nominal subject              extend
# this work                           work               direct object                extend
# the predictor variables             variables          object of preposition        Among
# geographic de-
# rates                rates              object of preposition        for
# the interaction                     interaction        appositional modifier        research
# poverty levels                      levels             object of preposition        between
# housing pendencies                  pendencies         conjunct                     levels
# longer temporal datasets            datasets           direct object                leveraging
# prices                              prices             object of preposition        to
# population density                  density            conjunct                     prices
# educational attainment              attainment         conjunct                     density
# dynamic housing trends              trends             direct object                capture
# time                                time               object of preposition        over

# %% [markdown]
# ---
# ## 6. Dependency Parsing with displaCy

# %%
# ── Dependency parse — longer passage ────────────────────────────────────
doc_object = nlp(u"""It is natural and right you should all go to homes of your own in time,
but I do want to keep my girls as long as I can, and I am sorry that this happened so soon,
for Meg is only seventeen and it will be some years before John can make a home for her""")

html = displacy.render(
    doc_object,
    style='dep',
    jupyter=False,
    options={
        'distance'     : 130,
        'color'        : 'blue',
        'arrow_stroke' : 4,
        'arrow_spacing': 20,
        'word_spacing' : 50,
        'compact'      : True
    }
)

display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="72702572957d4003ac2d9c5e9c0c313e-0" class="displacy" width="7720" height="609.0" direction="ltr" style="max-width: none; height: 609.0px; color: blue; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="180">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="180">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="310">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="310">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="440">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="440">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="570">right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="570">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="700">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="700">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">should</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">go</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">homes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="1740">own</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1740">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">time,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="2260">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2260">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="2520">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2520">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">want</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="2780">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2780">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">keep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="3040">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3040">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">girls</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="3300">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3300">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="3430">long</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3430">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="3560">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3560">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="3690">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3690">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="3820">can,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3820">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="509.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text

# %%
# ── Named entities in the same passage ───────────────────────────────────
print('=== ENTITIES IN PASSAGE ===')
for entity in doc_object.ents:
    print(entity, entity.label_)
# Out:
# === ENTITIES IN PASSAGE ===
# Meg ORG
# only seventeen CARDINAL
# some years DATE
# John PERSON

# %%
# ── Dependency parse — shorter technical sentence ─────────────────────────
parse_sentence = 'Researchers at Google and OpenAI have published papers on named entity recognition.'
doc_parse = nlp(parse_sentence)

html = displacy.render(
    doc_parse,
    style='dep',
    jupyter=False,
    options={
        'distance'     : 120,
        'color'        : 'blue',
        'arrow_stroke' : 3,
        'arrow_spacing': 20,
        'word_spacing' : 45,
        'compact'      : True
    }
)

display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c44e4cbcb88540ca9cb9605f0327105f-0" class="displacy" width="1490" height="318.0" direction="ltr" style="max-width: none; height: 318.0px; color: blue; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Researchers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">OpenAI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">published</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">papers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">named</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">entity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="228.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">recognition.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c44e4cbcb88540ca9cb9605f0327105f-0-0" stroke-width="3px" d="M70,183.0 70,123.0 770.0,123.0 770.0,183.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c44e4cbcb88540ca9cb9605f0327105f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,185.0 L66,177.0 74,177.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c44e4cbcb88540ca9cb9605f0327105f-0-1" stroke-width="3px" d="M70,183.0 70,163.0 160.0,163.0 160.0,183.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c44e4cbcb88540ca9cb9605f0327105f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160.0,185.0 L164.0,177.0 156.0,177.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c44e4cbcb88540ca9cb9605f0327105f-0-2" stroke-width="3px" d="M190,183.0 190,163.0 280.0,163.0 280.0,183.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c44e4cbcb88540ca9cb9605f0327105f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280.0,185.0 L284.0,177.0 276.0,177.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c44e4cbcb88540ca9cb9605f0327105f-0-3" stroke-width="3px" d="M310,183.0 310,163.0 400.0,163.0 400.0,183.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c44e4cbcb88540ca9cb9605f0327105f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,185.0 L404.0,177.0 396.0,177.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c44e4cbcb88540ca9cb9605f0327105f-0-4" stroke-width="3px" d="M310,183.0 310,143.0 525.0,143.0 525.0,183.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c44e4cbcb88540ca9cb9605f0327105f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,185.0 L529.0,177.0 521.0,177.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c44e4cbcb88540ca9cb9605f0327105f-0-5" stroke-width="3px" d="M670,183.0 670,163.0 760.0,163.0 760.0,183.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c44e4cbcb88540ca9cb9605f0327105f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,185.0 L666,177.0 674,177.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c44e4cbcb88540ca9cb9605f0327105f-0-6" stroke-width="3px" d="M790,183.0 790,163.0 880.0,163.0 880.0,183.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c44e4cbcb88540ca9cb9605f0327105f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M880.0,185.0 L884.0,177.0 876.0,177.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c44e4cbcb88540ca9cb9605f0327105f-0-7" stroke-width="3px" d="M790,183.0 790,143.0 1005.0,143.0 1005.0,183.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c44e4cbcb88540ca9cb9605f0327105f-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1005.0,185.0 L1009.0,177.0 1001.0,177.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id

# %% [markdown]
# ---
# ## 7. Bag-of-Words Feature Extraction
#
# A **Bag-of-Words (BoW)** representation converts text into a fixed-vocabulary count matrix:
# each row is a *document* (here, one sentence from the OCR output) and each column is a
# vocabulary term. Values are raw term counts. This is the simplest text feature representation
# and underpins many downstream models (Naive Bayes, logistic regression, clustering).
#
# We use `sklearn.feature_extraction.text.CountVectorizer` and treat each sentence of the
# OCR text as a separate "document" so that we can demonstrate term-document statistics on a
# single source image.

# %%
# ── Bag-of-Words on OCR text ───────────────────────────────────────
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import re

# Split the OCR output into sentence-level "documents"
sentences = [s.strip() for s in re.split(r'[.!?\n]+', ocr_text) if len(s.strip()) > 4]
print(f'Treating {len(sentences)} sentences as documents for BoW / TF-IDF analysis.')

bow_vectoriser = CountVectorizer(stop_words='english', lowercase=True, min_df=1)
bow_matrix    = bow_vectoriser.fit_transform(sentences)

bow_df = pd.DataFrame(
    bow_matrix.toarray(),
    columns=bow_vectoriser.get_feature_names_out(),
    index=[f'sent_{i+1}' for i in range(len(sentences))]
)

print(f'\nBoW matrix shape: {bow_matrix.shape}  (documents x vocabulary)')

# Top 15 most frequent terms across the whole corpus
totals = bow_df.sum(axis=0).sort_values(ascending=False)
print('\n=== Top 15 BoW terms (raw counts) ===')
print(totals.head(15).to_string())

# Preview the first few rows of the matrix (showing only columns that fire)
preview_cols = totals.head(10).index.tolist()
bow_df[preview_cols].head(10)
# Out:
# Treating 61 sentences as documents for BoW / TF-IDF analysis.
#
# BoW matrix shape: (61, 207)  (documents x vocabulary)
#
# === Top 15 BoW terms (raw counts) ===
# homeownership    15
# county            8
# housing           8
# level             5
# models            5
# rates             4
# rate              4
# results           4
# historical        4
# feature           4
# forest            4
# importance        4
# acs               4
# data              3
# features          3
#          homeownership  county  housing  level  models  rates  rate  results  \
# sent_1               1       1        0      0       0      0     1        0
# sent_2               1       0        0      0       0      0     0        0
# sent_3               0       0        0      0       0      0     0        0
# sent_4               1       0        0      0       0      0     0        0
# sent_5               0       0        0      0       0      0     0        0
# sent_6               0       0        0      0       0      0     0        1
# sent_7               0       0        0      0       0      0     0        0
# sent_8               1       1        0      1       0      0     0        0
# sent_9               0       0        1      0       0      0     0        0
# sent_10              0       0        0      0       0      0     0        0
#
#          historical  feature
# sent_1            1        1
# sent_2            0        0
# sent_3            0        0
# sent_4            0        0
# sent_5            0        1
# sent_6            0        0
# sent_7            1        0
# sent_8            0        0
# sent_9            0        0
# sent_10           0        0

# %% [markdown]
# ---
# ## 8. TF-IDF Feature Extraction
#
# **TF-IDF (Term Frequency – Inverse Document Frequency)** down-weights terms that appear in
# many documents (e.g. *the*, *and*) and up-weights terms that are concentrated in a few
# documents — these are usually the most informative for distinguishing one document from
# another.
#
# We use `TfidfVectorizer` with `sublinear_tf=True` (logarithmic term-frequency scaling, which
# dampens the effect of repeated words within a sentence) and inspect:
#
# - the highest-weighted terms across the whole document, and
# - the single strongest term per sentence (a quick "topic" indicator for each line).

# %%
# ── TF-IDF on the same sentence-level corpus ────────────────────
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectoriser = TfidfVectorizer(
    stop_words='english',
    lowercase=True,
    min_df=1,
    sublinear_tf=True
)
tfidf_matrix = tfidf_vectoriser.fit_transform(sentences)

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=tfidf_vectoriser.get_feature_names_out(),
    index=[f'sent_{i+1}' for i in range(len(sentences))]
)

print(f'TF-IDF matrix shape: {tfidf_matrix.shape}')

# Aggregate weights across the whole corpus
weights = tfidf_df.sum(axis=0).sort_values(ascending=False)
print('\n=== Top 15 TF-IDF weighted terms ===')
print(weights.head(15).round(3).to_string())

# Strongest TF-IDF term in each sentence (a lightweight "what is this line about?")
print('\n=== Strongest TF-IDF term per sentence (first 10) ===')
for i in range(min(10, len(sentences))):
    row = tfidf_df.iloc[i]
    if row.sum() > 0:
        top_term   = row.idxmax()
        top_weight = row.max()
        snippet    = sentences[i][:65].replace('\n', ' ')
        print(f'  sent_{i+1:>2}: "{top_term}"  (w={top_weight:.2f})  | {snippet}')
# Out:
# TF-IDF matrix shape: (61, 207)
#
# === Top 15 TF-IDF weighted terms ===
# homeownership    3.966
# county           2.359
# housing          2.300
# level            1.921
# results          1.877
# 880              1.732
# rate             1.638
# models           1.589
# forest           1.476
# neural           1.389
# performance      1.382
# networks         1.352
# importance       1.333
# feature          1.309
# evaluated        1.302
#
# === Strongest TF-IDF term per sentence (first 10) ===
#   sent_ 1: "enhanced"  (w=0.30)  | someonnersip rte prev XGBoost Feature Importance (Enhanced with H
#   sent_ 2: "ony"  (w=0.49)  | peptone ony Pec Change in Homeownership
#   sent_ 3: "fig"  (w=0.71)  | ia Fig
#   sent_ 4: "evolution"  (w=0.88)  | Evolution of homeownership
#   sent_ 5: "factors"  (w=0.48)  | Random Forest feature importance as the most influential factors
#   sent_ 6: "highlight"  (w=0.78)  | These results highlight the
#   sent_ 7: "broader"  (w=0.49)  | importance of both historical persistence and broader socioe-
#   sent_ 8: "shaping"  (w=0.50)  | conomic conditions in shaping county-level homeownership
#   sent_ 9: "decreases"  (w=0.43)  | and decreases highlights the heterogeneous nature of housing patt
#   sent_10: "model"  (w=0.50)  | In terms of model performance, Random Forest

# %% [markdown]
# ---
# ## 9. Section Categorisation — Titles, Body & Captions
#
# The brief asks for *"categorising sections (e.g., separating titles, body text, and captions)"*.
# With OCR output as a flat string, we apply lightweight rules to each non-empty line:
#
# | Class       | Heuristic                                                           |
# |-------------|----------------------------------------------------------------------|
# | `caption`   | Line starts with *Figure / Fig. / Table / Caption* + optional number |
# | `title`     | Short line (≤ 12 words) where ≥ 60% of words are capitalised, or ALL CAPS |
# | `body`      | Everything else (default)                                            |
#
# These are intentionally simple — a real system would combine font size, layout coordinates
# from the OCR engine (`image_to_data`), and visual cues from Phase 2. They give us a structured
# view of the document for downstream multi-modal integration in Phase 3.

# %%
# ── Rule-based section categorisation ────────────────────────────
import re
import pandas as pd

CAPTION_RE = re.compile(r'^(figure|fig\.?|table|tbl\.?|caption|chart|diagram)\s*\d*[:.\)]?',
                        re.IGNORECASE)

def categorise_line(line: str) -> str:
    s = line.strip()
    if not s:
        return 'empty'
    if CAPTION_RE.match(s):
        return 'caption'
    words = s.split()
    if len(words) <= 12 and len(s) <= 80:
        cap_ratio = sum(1 for w in words if w[:1].isupper()) / max(len(words), 1)
        if s.isupper() or cap_ratio >= 0.6:
            return 'title'
    return 'body'

lines        = [l for l in ocr_text.split('\n') if l.strip()]
categorised  = [(categorise_line(l), l.strip()) for l in lines]

# Summary counts
counts = pd.Series([c for c, _ in categorised]).value_counts()
print('=== Lines per section type ===')
print(counts.to_string())

# Show the categorisation for the first 20 lines
print('\n=== Categorised lines (first 20) ===')
for cat, line in categorised[:20]:
    print(f'[{cat.upper():<8}] {line[:80]}')

# Build a tidy DataFrame so the categorised output can be re-used in Phase 3
sections_df = pd.DataFrame(categorised, columns=['section_type', 'text'])
sections_df.head(10)
# Out:
# === Lines per section type ===
# body       40
# title       2
# caption     1
#
# === Categorised lines (first 20) ===
# [BODY    ] someonnersip rte prev XGBoost Feature Importance (Enhanced with Historical Featu
# [BODY    ] peptone ony Pec Change in Homeownership
# [BODY    ] ia Fig. 11. Evolution of homeownership
# [CAPTION ] Fig. 10. Random Forest feature importance as the most influential factors. These
# [BODY    ] importance of both historical persistence and broader socioe-
# [BODY    ] conomic conditions in shaping county-level homeownership
# [BODY    ] and decreases highlights the heterogeneous nature of housing patterns. In terms
# [BODY    ] market dynamics, suggesting that local economic conditions, achieved the highest
# [BODY    ] demographic trends, and housing supply constraints likely followed closely by Gr
# [BODY    ] contributed to differing outcomes across counties. Neural Networks (R? = 0.770).
# [BODY    ] ensemble tree-based models are particularly well-suited for
# [BODY    ] US County Homeownership Rate (2022 ACS) tabular socioeconomic data with nonlinea
# [BODY    ] omsounesnpaae | HUFal networks can still provide strong predictions but may
# [BODY    ] be constrained by dataset size and feature dimensionality.
# [BODY    ] * e In general, the results demonstrate that integrating historical
# [BODY    ] “ features into predictive models not only improves accuracy but
# [BODY    ] ” fo also provides valuable insights into the drivers of county-level
# [BODY    ] , 02 homeownership, offering practical implications for policymak-
# [BODY    ] = ~ : 5 ers and regional planners interested in housing stability and
# [BODY    ] economic development. However, several limitations exist:
#   section_type                                               text
# 0         body  someonnersip rte prev XGBoost Feature Importan...
# 1         body            peptone ony Pec Change in Homeownership
# 2         body             ia Fig. 11. Evolution of homeownership
# 3      caption  Fig. 10. Random Forest feature importance as t...
# 4         body  importance of both historical persistence and ...
# 5         body  conomic conditions in shaping county-level hom...
# 6         body  and decreases highlights the heterogeneous nat...
# 7         body  market dynamics, suggesting that local economi...
# 8         body  demographic trends, and housing supply constra...
# 9         body  contributed to differing outcomes across count...

# %% [markdown]
# ---
# ## 10. Sentiment Analysis
#
# The brief mentions sentiment analysis as one of the optional text-feature techniques.
# We use **VADER** (Valence Aware Dictionary and sEntiment Reasoner), a rule-based sentiment
# analyser tuned for short, social-media-style text — ideal for noisy OCR output where
# dependency-based models can struggle.
#
# VADER returns four scores per text:
#
# - `pos`, `neu`, `neg` — proportion of the text in each polarity bucket (sum to 1.0)
# - `compound` — a single normalised score in [-1, +1] (the standard summary)
#
# Conventional thresholds: **compound ≥ +0.05 → positive**, **≤ −0.05 → negative**, otherwise neutral.

# %%
# ── Sentiment analysis with VADER ────────────────────────────────
import nltk
# Had to manual download the vader_lexicon
#nltk.download('vader_lexicon', quiet=True)
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

# Whole-document sentiment
overall = sia.polarity_scores(ocr_text)
print('=== Overall document sentiment ===')
for k, v in overall.items():
    print(f'  {k:<10}: {v:+.3f}')

if   overall['compound'] >=  0.05: label = 'POSITIVE'
elif overall['compound'] <= -0.05: label = 'NEGATIVE'
else:                              label = 'NEUTRAL'
print(f'\n  -> Document classified as {label} (compound = {overall["compound"]:+.3f})')

# Per-sentence sentiment for the first 10 sentences
print('\n=== Per-sentence sentiment (first 10) ===')
for i, sent in enumerate(sentences[:10]):
    s = sia.polarity_scores(sent)
    snippet = sent[:65].replace('\n', ' ')
    print(f'  [compound={s["compound"]:+.2f}] {snippet}')
# Out:
# === Overall document sentiment ===
#   neg       : +0.018
#   neu       : +0.846
#   pos       : +0.136
#   compound  : +0.995
#
#   -> Document classified as POSITIVE (compound = +0.995)
#
# === Per-sentence sentiment (first 10) ===
#   [compound=+0.36] someonnersip rte prev XGBoost Feature Importance (Enhanced with H
#   [compound=+0.00] peptone ony Pec Change in Homeownership
#   [compound=+0.00] ia Fig
#   [compound=+0.00] Evolution of homeownership
#   [compound=+0.69] Random Forest feature importance as the most influential factors
#   [compound=+0.34] These results highlight the
#   [compound=+0.36] importance of both historical persistence and broader socioe-
#   [compound=+0.00] conomic conditions in shaping county-level homeownership
#   [compound=+0.00] and decreases highlights the heterogeneous nature of housing patt
#   [compound=+0.00] In terms of model performance, Random Forest

# %% [markdown]
# ---
# # Image Feature Engineering Pipeline
# ### Preprocessing → Feature Detection → Document Binarisation → Region Labelling → Bounding-Box Visualisation
# ---
# This section processes the **same** document used in Phase 1 (`paper_p1.png` — page 1 of
# the academic paper *Predicting County-Level Homeownership Rates …*, rendered from PDF at 200 DPI). The unified input means the OCR text from Phase 1 and the layout regions
# detected here describe the same physical page, which sets up the multi-modal integration
# in Phase 3.
#
# Techniques are drawn from the WK6 lab code (`cv2.imread`, `cv2.cvtColor`, `cv2.GaussianBlur`,
# `cv2.threshold`, `cv2.rectangle`, `cv2.putText`) plus a small number of additional OpenCV
# operations referenced inline (Canny, Shi–Tomasi, morphology, connected components):
#
# - detect structural features (Canny edges, Shi–Tomasi corner keypoints, Otsu binarisation)
# - merge characters into block-level layout regions via morphological closing
# - run connected components on the block mask and classify each region by shape into
#   **header**, **figure**, **paragraph**, **text_line**, or **other**
# - draw colour-coded bounding boxes and produce a summary DataFrame with geometry stats
#
# Section 2.7 at the end of Phase 2 re-runs the pipeline on two non-document images
# (`MyBook.jpg`, `seaside.jpg`) as a robustness check.

# %% [markdown]
# ## 2.0  Additional Imports for Image Feature Engineering

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from collections import Counter
import pandas as pd

print(f'OpenCV version: {cv2.__version__}')
print('Scene feature engineering imports ready.')
# Out:
# OpenCV version: 4.13.0
# Scene feature engineering imports ready.

# %% [markdown]
# ---
# ## 2.1  Image Preprocessing Pipeline
#
# Phase 2 operates on the **same** `paper_p1.png` document used in Phase 1 (page 1 of the
# homeownership-rates paper), so the text extracted by OCR and the regions detected here
# describe the same physical page. This sets up the multi-modal analysis intended for Phase 3.
#
# Three preparation steps follow the WK6 lab pattern (`cv2.imread` -> `cv2.cvtColor`
# -> `cv2.GaussianBlur`):
#
# | Step | OpenCV call | Purpose |
# |------|-------------|---------|
# | RGB conversion | `cv2.cvtColor(..., COLOR_BGR2RGB)` | OpenCV reads BGR; Matplotlib expects RGB *(WK6 lab)* |
# | Grayscale       | `cv2.cvtColor(..., COLOR_BGR2GRAY)` | Single-channel intensity for thresholding & edge detection *(WK6 lab)* |
# | Gaussian blur   | `cv2.GaussianBlur(..., (5,5), 0)`   | Smooths scan noise / paper grain before binarisation *(WK6 lab)* |
#
# The HSV channel is also computed; it is only used in the optional non-document
# stress test in Section 2.7.

# %%
# ── Load the primary document image (same as Phase 1) ─────────────
# Pattern from WK6 Lab Code: cv2.imread + cvtColor + GaussianBlur.
IMAGE_FILE = 'paper_p1.png'

img_bgr = cv2.imread(IMAGE_FILE)
if img_bgr is None:
    raise FileNotFoundError(
        f"Could not load '{IMAGE_FILE}'. "
        "Ensure the document image is in the same directory as this notebook."
    )

# ── Step 1 — Colour-space conversions (WK6 lab) ────────────────────
img_rgb  = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)   # for Matplotlib display
img_hsv  = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)   # used by stress test 2.7.2
img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)  # for thresholding / edges

# ── Step 2 — Noise reduction (WK6 lab) ─────────────────────────────
img_blur = cv2.GaussianBlur(img_gray, (5, 5), 0)

H, W = img_gray.shape
print(f'Image size            : {W} x {H} pixels')
print(f'Mean intensity (gray) : {img_blur.mean():.1f}')

# ── Display preprocessing stages ───────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(14, 6))
axes[0].imshow(img_rgb);                  axes[0].set_title('Original (RGB)',           fontsize=12)
axes[1].imshow(img_gray, cmap='gray');    axes[1].set_title('Grayscale',                fontsize=12)
axes[2].imshow(img_blur, cmap='gray');    axes[2].set_title('Grayscale + Gaussian blur', fontsize=12)
for ax in axes: ax.axis('off')
plt.tight_layout(); plt.show()
# Out:
# Image size            : 1700 x 2200 pixels
# Mean intensity (gray) : 236.7

# %% [markdown]
# ---
# ## 2.2  Feature Detection — Edges, Corners, and Document Binarisation
#
# Three feature-detection passes describe what's on the page:
#
# - **Canny edge detection** picks up borders of text blocks, the page grid,
#   paper headings, figure rules, and inline tables/equations.
#   *Reference: OpenCV Canny tutorial — https://docs.opencv.org/4.x/da/d22/tutorial_py_canny.html*
# - **Shi–Tomasi corner keypoints** (`cv2.goodFeaturesToTrack`) cluster around
#   table cells and around hard-edged graphical elements (figures, banners, inline math).
#   *Reference: OpenCV goodFeaturesToTrack tutorial — https://docs.opencv.org/4.x/d4/d8c/tutorial_py_shi_tomasi.html*
# - **Otsu binarisation** (`cv2.threshold` with `THRESH_BINARY_INV + THRESH_OTSU`)
#   comes from the WK6 lab. Otsu auto-picks the threshold that best separates the
#   bimodal text/background histogram, producing a binary mask with text = white
#   and paper = black. A horizontal morphological close then merges adjacent
#   characters and lines into paragraph blobs.
#   *References: WK6 lab `cv2.threshold` examples; OpenCV thresholding tutorial
#   https://docs.opencv.org/4.x/d7/d4d/tutorial_py_thresholding.html ; OpenCV
#   morphology tutorial https://docs.opencv.org/4.x/d9/d61/tutorial_py_morphological_ops.html*

# %%
# ── Canny edge detection ───────────────────────────────────────
# Reference: OpenCV Canny tutorial
# https://docs.opencv.org/4.x/da/d22/tutorial_py_canny.html
edges = cv2.Canny(img_blur, threshold1=60, threshold2=160)

# ── Shi–Tomasi corner keypoints ────────────────────────────────
# Reference: OpenCV goodFeaturesToTrack tutorial
# https://docs.opencv.org/4.x/d4/d8c/tutorial_py_shi_tomasi.html
corners = cv2.goodFeaturesToTrack(
    img_blur, maxCorners=400, qualityLevel=0.01, minDistance=10
)
img_corners = img_rgb.copy()
if corners is not None:
    for pt in corners.astype(int).reshape(-1, 2):
        cv2.circle(img_corners, tuple(pt), 4, (255, 0, 0), -1)

# ── Otsu binarisation (WK6 Lab — cv2.threshold) ─────────────────
# THRESH_BINARY_INV : flip output so text -> 255, background -> 0
# THRESH_OTSU       : auto-pick threshold from the image histogram
otsu_value, binary = cv2.threshold(
    img_blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU
)
print(f'Otsu auto-threshold value: {otsu_value:.0f}')

# ── Group characters into text blocks via morphological closing ─
# A horizontal kernel merges adjacent characters into line blobs;
# the slight vertical extent merges line blobs into paragraph blobs.
# Reference: OpenCV morphology tutorial
# https://docs.opencv.org/4.x/d9/d61/tutorial_py_morphological_ops.html
block_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (60, 12))
block_mask   = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, block_kernel)

# Single-mask layout pipeline: each connected component of `block_mask`
# is one document region. Sec. 2.3 classifies them by shape.
masks = {'block': block_mask}

# ── Stats ──────────────────────────────────────────────────────
print(f'Canny edge pixels : {int(edges.sum() // 255):,}')
print(f'Corner keypoints  : {0 if corners is None else len(corners)}')
print(f'Block mask pixels : {int(block_mask.sum() // 255):,} '
      f'({100 * int(block_mask.sum() // 255) / (H * W):.1f}% of page)')

# ── Visualisation ──────────────────────────────────────────────
fig, axes = plt.subplots(2, 2, figsize=(14, 14))
axes[0, 0].imshow(edges, cmap='gray');      axes[0, 0].set_title('Canny edges')
axes[0, 1].imshow(img_corners);             axes[0, 1].set_title('Shi–Tomasi corners')
axes[1, 0].imshow(binary, cmap='gray');     axes[1, 0].set_title(f'Otsu binary (threshold={otsu_value:.0f})')
axes[1, 1].imshow(block_mask, cmap='gray'); axes[1, 1].set_title('Block mask after morphology')
for ax in axes.ravel():
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Otsu auto-threshold value: 188
# Canny edge pixels : 230,697
# Corner keypoints  : 400
# Block mask pixels : 903,854 (24.2% of page)

# %% [markdown]
# ---
# ## 2.3  Region Labelling — Classify Document Regions
#
# Each blob in `block_mask` is run through `cv2.connectedComponentsWithStats`
# and discarded if smaller than `MIN_AREA_RATIO` of the page. Surviving regions
# are then classified by **geometry plus ink-density** rules. The density
# rule was added after observing that filled charts on page 5 of the source
# paper were initially mis-classified as `paragraph` because they were
# landscape (aspect ≈ 1.7) and individually < 4% of the page — see the
# in-code comment in the next cell for the empirical numbers.
#
# | Region type | Rule (first match wins)                                                         | What it picks up |
# |-------------|----------------------------------------------------------------------------------|-------------------|
# | `header`    | Width > 50% of page **and** height < 100 px                                      | Title bar / section banners (e.g. paper title, running heads) |
# | `figure`    | **Foreground density > 0.40** in the raw Otsu mask **and** area > 0.5% of page  | Filled charts, bar graphs, photographs |
# | `figure`    | Aspect ≈ 1, area > 4% of page  *(legacy geometric fallback)*                     | Square logos, info tables |
# | `text_line` | Aspect > 4 **and** height < 60 px                                                | A single line of body text |
# | `paragraph` | Anything else (default)                                                          | Multi-line body paragraphs |
# | `other`     | Whatever the priority chain didn't claim                                         | Margin space, isolated marks |
#
# *References for the density-based rule:*
# - *Wong, Casey & Wahl (1982). "Document Analysis System." IBM Journal of Research and Development, 26(6), 647–656. https://doi.org/10.1147/rd.266.0647*
# - *Leptonica (Bloomberg) — https://www.leptonica.org/papers.html*
#
# *Reference for `cv2.connectedComponentsWithStats`:*
# *https://docs.opencv.org/4.x/d3/dc0/group__imgproc__shape.html*

# %%
# ── Region colour palette for document layout ────────────────────
# Chosen to contrast against a white page so the bounding boxes pop.
REGION_COLOURS = {
    'header'    : ( 30,  60, 200),   # deep blue
    'figure'    : ( 40, 160,  60),   # green
    'paragraph' : (220, 120,   0),   # orange
    'text_line' : (110, 110, 110),   # grey
    'other'     : (220,  20,  60),   # crimson
}

MIN_AREA_RATIO = 0.001           # discard blobs < 0.1% of page area
min_area       = int(MIN_AREA_RATIO * H * W)


# ─────────────────────────────────────────────────────────────────────
# Region classifier — geometry rules + foreground-density signal
# ─────────────────────────────────────────────────────────────────────
# ISSUE (observed on page 5 of the source PDF):
#   The original classifier used purely geometric rules — a region was
#   tagged 'figure' only if it was square-ish (0.6 < aspect < 1.6) AND
#   occupied > 4% of the page. That stencil matched the original test
#   document (a logo + an info table) but missed typical research-paper
#   charts: the three filled charts on page 5 had aspect 1.68–1.74 and
#   each occupied ~2% of the page, so they fell through to the default
#   'paragraph' bucket in Sec. 3.3 / 2.4.
#
# FIX (density-based discriminator):
#   Inside the *raw* Otsu mask (`binary`, before the morphological close
#   that builds `block_mask`), each region has a foreground-pixel
#   density that separates filled graphics from text very cleanly:
#
#       paragraphs / headers / text lines :  fg_ratio ~ 0.10 - 0.30
#       filled charts / images            :  fg_ratio ~ 0.55 - 0.60
#
#   A threshold of fg_ratio > 0.40 catches filled figures regardless of
#   aspect ratio. The legacy "square-and-large" rule is kept as a second
#   trigger for square logos/tables that may have lower ink density.
#
# REFERENCES (also listed in the References section at the end):
#   - Wong, K. Y., Casey, R. G., & Wahl, F. M. (1982). "Document
#     analysis system." IBM Journal of Research and Development, 26(6),
#     647-656. https://doi.org/10.1147/rd.266.0647
#     The foundational paper for Run-Length Smoothing + foreground-
#     density classification of printed-page blocks; the classical
#     alternative to deep-learning layout models such as LayoutParser.
#   - Bloomberg, D. S. "Multiresolution Morphological Approach to
#     Document Image Analysis" — the Leptonica library (used internally
#     by Tesseract) applies the same density-vs-text discriminator for
#     halftone/figure detection. https://www.leptonica.org/papers.html
# ─────────────────────────────────────────────────────────────────────
def classify_region(x, y, w, h, raw_mask=None):
    """Classify a detected document region by geometry + ink density.

    See the long comment above for the rationale and references.
    `raw_mask` is the un-closed Otsu binary image (`binary` from Sec.
    2.2). When provided, a region whose bounding box has foreground
    density > 0.40 is tagged as a figure regardless of aspect ratio.
    """
    aspect = w / max(h, 1)
    area   = w * h

    # 1. Header — full-width banner (unchanged from original rule)
    if w > 0.50 * W and h < 100:
        return 'header'

    # 2. Density-based figure rule (NEW — see comment above)
    #    Catches landscape / column-width charts with high ink fill.
    if raw_mask is not None and area > 0.005 * H * W:
        fg_ratio = float(raw_mask[y:y + h, x:x + w].sum()) / 255.0 / area
        if fg_ratio > 0.40:
            return 'figure'

    # 3. Geometric figure rule (kept as fallback for square logos /
    #    info tables where ink density alone may be ambiguous)
    if 0.6 < aspect < 1.6 and area > 0.04 * H * W:
        return 'figure'

    # 4. Single line of body text
    if aspect > 4 and h < 60:
        return 'text_line'

    # 5. Default
    return 'paragraph'


def extract_regions_from_mask(mask, default_label, raw_mask=None):
    """Run connected components on a binary mask and return (x,y,w,h,label) tuples
    for every blob larger than `min_area`.

    For the document mask (default_label == 'block') the per-region label is
    overridden by the shape-and-density classifier above. Other masks pass
    their label through unchanged (used by the colour-mask stress test in
    Sec. 2.7).

    `raw_mask` is forwarded to classify_region so the density rule can fire.

    Reference: OpenCV connectedComponentsWithStats —
    https://docs.opencv.org/4.x/d3/dc0/group__imgproc__shape.html
    """
    n, _labels, stats, _ = cv2.connectedComponentsWithStats(mask, connectivity=8)
    out = []
    for i in range(1, n):                      # skip background (label 0)
        x, y, w, h, area = stats[i]
        if area < min_area:
            continue
        if default_label == 'block':
            label = classify_region(x, y, w, h, raw_mask=raw_mask)
        else:
            label = default_label
        out.append((int(x), int(y), int(w), int(h), label))
    return out


# ── Gather components from every supplied mask ───────────────────
# `binary` (raw Otsu mask from Sec. 2.2) is passed in so the density-
# based figure rule can see un-closed ink coverage.
region_records = []
for name, mask in masks.items():
    region_records.extend(
        extract_regions_from_mask(mask, name, raw_mask=binary)
    )

# ── "Other" — any sizeable area not claimed by the block mask ────
covered = np.zeros_like(img_gray, dtype=np.uint8)
for m in masks.values():
    covered |= m
uncovered = cv2.bitwise_not(covered)
uncovered = cv2.morphologyEx(uncovered, cv2.MORPH_OPEN,  np.ones((9, 9),   np.uint8))
uncovered = cv2.morphologyEx(uncovered, cv2.MORPH_CLOSE, np.ones((11, 11), np.uint8))
masks['other'] = uncovered
region_records.extend(extract_regions_from_mask(uncovered, 'other'))

# Draw largest regions first so small ones sit on top
region_records.sort(key=lambda r: r[2] * r[3], reverse=True)

print(f'Detected {len(region_records)} regions >= {MIN_AREA_RATIO:.1%} of page area')
type_counts = Counter(r[4] for r in region_records)
for t in REGION_COLOURS:
    print(f'  {t:<11}: {type_counts.get(t, 0):>3}')
# Out:
# Detected 19 regions >= 0.1% of page area
#   header     :   1
#   figure     :   3
#   paragraph  :   5
#   text_line  :   6
#   other      :   4

# %% [markdown]
# ---
# ## 2.4  Bounding-Box Visualisation
#
# Colour-coded bounding boxes and region labels are drawn using `cv2.rectangle` and `cv2.putText`
# (following the WK6 lab style). A Matplotlib legend maps colours to region types.

# %%
# ── Draw bounding boxes and text labels ────────────────────
# Uses REGION_COLOURS defined in Sec. 2.3.
# cv2.rectangle / cv2.putText pattern: WK6 Lab Code.
annotated = img_rgb.copy()
font = cv2.FONT_HERSHEY_SIMPLEX

for (x, y, w, h, rtype) in region_records:

    colour = REGION_COLOURS.get(rtype, (200, 200, 200))   # fallback grey
    label  = rtype.replace('_', ' ').title()

    # Bounding rectangle
    cv2.rectangle(annotated, (x, y), (x + w, y + h), colour, 2)

    # Filled label background then white text
    (tw, th), _ = cv2.getTextSize(label, font, 0.50, 1)
    cv2.rectangle(annotated, (x, max(y - th - 6, 0)), (x + tw + 6, y), colour, -1)
    cv2.putText(annotated, label, (x + 3, max(y - 4, th + 2)),
                font, 0.50, (255, 255, 255), 1, cv2.LINE_AA)

# ── Show the annotated document ───────────────────────
fig, ax = plt.subplots(figsize=(10, 13))
ax.imshow(annotated)
ax.axis('off')
plt.suptitle('2.4 — Document Layout Region Detection',
             fontsize=14, fontweight='bold')

# Legend
legend_patches = [mpatches.Patch(color=np.array(c) / 255, label=t.replace('_', ' ').title())
                  for t, c in REGION_COLOURS.items()]
ax.legend(handles=legend_patches, loc='lower right', framealpha=0.85)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 2.5  Per-Region Crop Gallery
#
# The three largest detected regions of each type are cropped and displayed for visual inspection.
# Coloured spine borders match the bounding-box colour scheme.

# %%
MAX_EXAMPLES = 3

for rtype, colour in REGION_COLOURS.items():
    examples = [(x, y, w, h) for (x, y, w, h, rt) in region_records if rt == rtype]
    if not examples:
        print(f'[{rtype}] No regions detected.')
        continue

    # Sort largest-first, take up to MAX_EXAMPLES
    examples.sort(key=lambda r: r[2] * r[3], reverse=True)
    show = examples[:MAX_EXAMPLES]
    colour_norm = tuple(c / 255 for c in colour)

    fig, axes = plt.subplots(1, len(show), figsize=(5 * len(show), 4))
    if len(show) == 1:
        axes = [axes]
    for ax, (x, y, w, h) in zip(axes, show):
        crop = img_rgb[y:y + h, x:x + w]
        ax.imshow(crop)
        ax.set_title(f'{rtype} ({w}×{h})', fontsize=10)
        ax.axis('off')
        for spine in ax.spines.values():
            spine.set_visible(True)
            spine.set_edgecolor(colour_norm)
            spine.set_linewidth(3)
    plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 2.6  Pipeline Summary — Region Feature Table
#
# All detected regions are compiled into a DataFrame with geometry (position, size, aspect) **and**
# colour descriptors (mean H / S / V over the bounding box). Styled cells use a heatmap to highlight
# the largest / most saturated regions.

# %%
rows = []
for (x, y, w, h, rtype) in region_records:
    area   = w * h
    aspect = round(w / (h + 1e-6), 2)

    # Fill ratio = fraction of bbox inside this region's own colour mask
    ref_mask = masks.get(rtype, uncovered)
    fg       = int((ref_mask[y:y + h, x:x + w] > 0).sum())
    fill     = round(fg / (area + 1e-6), 3)

    # Mean HSV inside the bounding box — colour fingerprint of the region
    crop_hsv = img_hsv[y:y + h, x:x + w]
    mean_h   = round(float(crop_hsv[:, :, 0].mean()), 1)
    mean_s   = round(float(crop_hsv[:, :, 1].mean()), 1)
    mean_v   = round(float(crop_hsv[:, :, 2].mean()), 1)

    rows.append({
        'Region Type'  : rtype,
        'X'            : x,
        'Y'            : y,
        'Width'        : w,
        'Height'       : h,
        'Area (px^2)'  : area,
        'Aspect (w/h)' : aspect,
        'Fill Ratio'   : fill,
        'Mean H'       : mean_h,
        'Mean S'       : mean_s,
        'Mean V'       : mean_v,
    })

df_regions = (
    pd.DataFrame(rows)
      .sort_values(['Region Type', 'Area (px^2)'], ascending=[True, False])
      .reset_index(drop=True)
)

print(f'Total regions in summary table: {len(df_regions)}')
(df_regions.style
    .background_gradient(subset=['Area (px^2)'],  cmap='YlOrBr')
    .background_gradient(subset=['Fill Ratio'],   cmap='Greens')
    .background_gradient(subset=['Mean S'],       cmap='PuRd')
    .set_caption('Detected Scene Regions — Sorted by Type & Area')
    .set_table_styles([{'selector': 'caption',
                        'props': [('font-size', '13px'),
                                  ('font-weight', 'bold')]}]))
# Out:
# Total regions in summary table: 19
# <style type="text/css">
# #T_c3e68 caption {
#   font-size: 13px;
#   font-weight: bold;
# }
# #T_c3e68_row0_col5, #T_c3e68_row1_col5 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_c3e68_row0_col7 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_c3e68_row0_col9 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_c3e68_row1_col7 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_c3e68_row1_col9 {
#   background-color: #cc9ecc;
#   color: #000000;
# }
# #T_c3e68_row2_col5 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_c3e68_row2_col7 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_c3e68_row2_col9 {
#   background-color: #b0084b;
#   color: #f1f1f1;
# }
# #T_c3e68_row3_col5 {
#   background-color: #fffddb;
#   color: #000000;
# }
# #T_c3e68_row3_col7 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_c3e68_row3_col9, #T_c3e68_row5_col9, #T_c3e68_row6_col9, #T_c3e68_row7_col9, #T_c3e68_row11_col9, #T_c3e68_row12_col9, #T_c3e68_row13_col9, #T_c3e68_row14_col9, #T_c3e68_row15_col9, #T_c3e68_row16_col9, #T_c3e68_row17_col9, #T_c3e68_row18_col9 {
#   background-color: #f7f4f9;
#   color: #000000;
# }
# #T_c3e68_row4_col5 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_c3e68_row4_col7 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_c3e68_row4_col9 {
#   background-color: #f0ecf5;
#   color: #000000;
# }
# #T_c3e68_row5_col5, #T_c3e68_row13_col5 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_c3e68_row5_col7 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_c3e68_row6_col5, #T_c3e68_row7_col5, #T_c3e68_row14_col5, #T_c3e68_row15_col5, #T_c3e68_row16_col5, #T_c3e68_row17_col5, #T_c3e68_row18_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_c3e68_row6_col7 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_c3e68_row7_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c3e68_row8_col5 {
#   background-color: #feeca4;
#   color: #000000;
# }
# #T_c3e68_row8_col7 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_c3e68_row8_col9 {
#   background-color: #e8e2f0;
#   color: #000000;
# }
# #T_c3e68_row9_col5 {
#   background-color: #fff0ad;
#   color: #000000;
# }
# #T_c3e68_row9_col7 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_c3e68_row9_col9 {
#   background-color: #ede9f3;
#   color: #000000;
# }
# #T_c3e68_row10_col5 {
#   background-color: #fff7be;
#   color: #000000;
# }
# #T_c3e68_row10_col7 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_c3e68_row10_col9 {
#   background-color: #e3d8ea;
#   color: #000000;
# }
# #T_c3e68_row11_col5 {
#   background-color: #ffface;
#   color: #000000;
# }
# #T_c3e68_row11_col7 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_c3e68_row12_col5 {
#   background-color: #fffbd2;
#   color: #000000;
# }
# #T_c3e68_row12_col7 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_c3e68_row13_col7 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_c3e68_row14_col7 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_c3e68_row15_col7 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_c3e68_row16_col7 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_c3e68_row17_col7 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_c3e68_row18_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_c3e68">
#   <caption>Detected Scene Regions — Sorted by Type & Area</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3e68_level0_col0" class="col_heading level0 col0" >Region Type</th>
#       <th id="T_c3e68_level0_col1" class="col_heading level0 col1" >X</th>
#       <th id="T_c3e68_level0_col2" class="col_heading level0 col2" >Y</th>
#       <th id="T_c3e68_level0_col3" class="col_heading level0 col3" >Width</th>
#       <th id="T_c3e68_level0_col4" class="col_heading level0 col4" >Height</th>
#       <th id="T_c3e68_level0_col5" class="col_heading level0 col5" >Area (px^2)</th>
#       <th id="T_c3e68_level0_col6" class="col_heading level0 col6" >Aspect (w/h)</th>
#       <th id="T_c3e68_level0_col7" class="col_heading level0 col7" >Fill Ratio</th>
#       <th id="T_c3e68_level0_col8" class="col_heading level0 col8" >Mean H</th>
#       <th id="T_c3e68_level0_col9" class="col_heading level0 col9" >Mean S</th>
#       <th id="T_c3e68_level0_col10" class="col_heading level0 col10" >Mean V</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3e68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3e68_row0_col0" class="data row0 col0" >figure</td>
#       <td id="T_c3e68_row0_col1" class="data row0 col1" >245</td>
#       <td id="T_c3e68_row0_col2" class="data row0 col2" >1291</td>
#       <td id="T_c3e68_row0_col3" class="data row0 col3" >379</td>
#       <td id="T_c3e68_row0_col4" class="data row0 col4" >214</td>
#       <td id="T_c3e68_row0_col5" class="data row0 col5" >81106</td>
#       <td id="T_c3e68_row0_col6" class="data row0 col6" >1.770000</td>
#       <td id="T_c3e68_row0_col7" class="data row0 col7" >0.344000</td>
#       <td id="T_c3e68_row0_col8" class="data row0 col8" >22.100000</td>
#       <td id="T_c3e68_row0_col9" class="data row0 col9" >88.500000</td>
#       <td id="T_c3e68_row0_col10" class="data row0 col10" >194.600000</td>
#     </tr>
#     <tr>
#       <th id="T_c3e68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3e68_row1_col0" class="data row1 col0" >figure</td>
#       <td id="T_c3e68_row1_col1" class="data row1 col1" >973</td>
#       <td id="T_c3e68_row1_col2" class="data row1 col2" >199</td>
#       <td id="T_c3e68_row1_col3" class="data row1 col3" >365</td>
#       <td id="T_c3e68_row1_col4" class="data row1 col4" >214</td>
#       <td id="T_c3e68_row1_col5" class="data row1 col5" >78110</td>
#       <td id="T_c3e68_row1_col6" class="data row1 col6" >1.710000</td>
#       <td id="T_c3e68_row1_col7" class="data row1 col7" >0.364000</td>
#       <td id="T_c3e68_row1_col8" class="data row1 col8" >57.700000</td>
#       <td id="T_c3e68_row1_col9" class="data row1 col9" >30.100000</td>
#       <td id="T_c3e68_row1_col10" class="data row1 col10" >201.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c3e68_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3e68_row2_col0" class="data row2 col0" >figure</td>
#       <td id="T_c3e68_row2_col1" class="data row2 col1" >257</td>
#       <td id="T_c3e68_row2_col2" class="data row2 col2" >913</td>
#       <td id="T_c3e68_row2_col3" class="data row2 col3" >364</td>
#       <td id="T_c3e68_row2_col4" class="data row2 col4" >213</td>
#       <td id="T_c3e68_row2_col5" class="data row2 col5" >77532</td>
#       <td id="T_c3e68_row2_col6" class="data row2 col6" >1.710000</td>
#       <td id="T_c3e68_row2_col7" class="data row2 col7" >0.362000</td>
#       <td id="T_c3e68_row2_col8" class="data row2 col8" >61.000000</td>
#       <td id="T_c3e68_row2_col9" class="data row2 col9" >72.400000</td>
#       <td id="T_c3e68_row2_col10" class="data row2 col10" >182.800000</td>
#     </tr>
#     <tr>
#       <th id="T_c3e68_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3e68_row3_col0" class="data row3 col0" >header</td>
#       <td id="T_c3e68_row3_col1" class="data row3 col1" >138</td>
#       <td id="T_c3e68_row3_col2" class="data row3 col2" >1906</td>
#       <td id="T_c3e68_row3_col3" class="data row3 col3" >1427</td>
#       <td id="T_c3e68_row3_col4" class="data row3 col4" >92</td>
#       <td id="T_c3e68_row3_col5" class="data row3 col5" >131284</td>
#       <td id="T_c3e68_row3_col6" class="data row3 col6" >15.510000</td>
#       <td id="T_c3e68_row3_col7" class="data row3 col7" >0.470000</td>
#       <td id="T_c3e68_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_c3e68_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_c3e68_row3_col10" class="data row3 col10" >221.600000</td>
#     </tr>
#     <tr>
#       <th id="T_c3e68_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3e68_row4_col0" class="data row4 col0" >other</td>
#       <td id="T_c3e68_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c3e68_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_c3e68_row4_col3" class="data row4 col3" >17

# %% [markdown]
# ---
# # 2.7  Robustness Check — Pipeline on Non-Document Images
#
# The brief frames the system around scanned documents, but a robust pipeline
# should also degrade gracefully on other input. Two stress tests:
#
# 1. **`MyBook.jpg`** — a book cover (text + illustration, almost a document).
#    The same Otsu + morphology + connected-components pipeline from Sections 2.1–2.4
#    is applied unchanged.
# 2. **`seaside.jpg`** — a beach photograph with no text. Document binarisation
#    has nothing meaningful to bite into, so this run uses the alternative
#    **HSV colour segmentation** strategy (`cv2.inRange` per scene class with a
#    priority chain).
#
# These are explicitly framed as supplementary; the headline demo for the
# assignment is the document analysis above.

# %% [markdown]
# ## 2.7.1  Stress Test 1 — Book cover (`MyBook.jpg`)
#
# Re-runs the document pipeline (binarisation -> morphology -> connected components
# -> bounding boxes) on a book cover.

# %%
# Apply the document pipeline to a book cover for comparison
ST1_FILE = 'MyBook.jpg'
st1_bgr  = cv2.imread(ST1_FILE)
if st1_bgr is None:
    raise FileNotFoundError(f"Could not load '{ST1_FILE}'")

st1_rgb  = cv2.cvtColor(st1_bgr, cv2.COLOR_BGR2RGB)
st1_gray = cv2.cvtColor(st1_bgr, cv2.COLOR_BGR2GRAY)
st1_blur = cv2.GaussianBlur(st1_gray, (5, 5), 0)
st1_H, st1_W = st1_gray.shape

# WK6-lab Otsu binarisation
_, st1_bin = cv2.threshold(st1_blur, 0, 255,
                           cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# Morphological closing to merge characters into blocks
k = cv2.getStructuringElement(cv2.MORPH_RECT, (40, 10))
st1_blocks = cv2.morphologyEx(st1_bin, cv2.MORPH_CLOSE, k)

# Connected components
n, _, stats, _ = cv2.connectedComponentsWithStats(st1_blocks, connectivity=8)
st1_min_area = int(0.002 * st1_H * st1_W)

annotated = st1_rgb.copy()
font = cv2.FONT_HERSHEY_SIMPLEX
kept = 0
for i in range(1, n):
    x, y, w, h, area = stats[i]
    if area < st1_min_area:
        continue
    kept += 1
    aspect = w / max(h, 1)
    if   w > 0.5 * st1_W and h < 100:                       label, colour = 'header',    (30, 60, 200)
    elif 0.6 < aspect < 1.6 and area > 0.04 * st1_H * st1_W: label, colour = 'figure',    (40, 160, 60)
    elif aspect > 4 and h < 60:                              label, colour = 'text_line', (110, 110, 110)
    else:                                                    label, colour = 'paragraph', (220, 120, 0)

    cv2.rectangle(annotated, (x, y), (x + w, y + h), colour, 2)
    (tw, th), _ = cv2.getTextSize(label, font, 0.5, 1)
    cv2.rectangle(annotated, (x, max(y - th - 6, 0)), (x + tw + 6, y), colour, -1)
    cv2.putText(annotated, label, (x + 3, max(y - 4, th + 2)),
                font, 0.5, (255, 255, 255), 1, cv2.LINE_AA)

print(f'Stress test 1 — kept {kept} regions')

fig, axes = plt.subplots(1, 2, figsize=(14, 8))
axes[0].imshow(st1_rgb);   axes[0].set_title('Original — MyBook.jpg')
axes[1].imshow(annotated); axes[1].set_title('Document pipeline applied')
for ax in axes: ax.axis('off')
plt.tight_layout(); plt.show()
# Out:
# Stress test 1 — kept 3 regions

# %% [markdown]
# ## 2.7.2  Stress Test 2 — Beach scene (`seaside.jpg`)
#
# Document binarisation finds nothing useful in a uniform-colour landscape, so
# the seaside image is segmented with **HSV colour masking** (`cv2.inRange`)
# plus a priority chain. This was the segmentation approach used in earlier
# drafts of the notebook and is preserved here as a supplementary demonstration
# of an alternative strategy.
#
# *References:* `cv2.inRange` — https://docs.opencv.org/4.x/d2/de8/group__core__array.html ;
# HSV colour space — OpenCV "Changing Colorspaces" tutorial:
# https://docs.opencv.org/4.x/df/d9d/tutorial_py_colorspaces.html

# %%
# HSV colour-based segmentation on a beach scene
ST2_FILE = 'seaside.jpg'
st2_bgr  = cv2.imread(ST2_FILE)
if st2_bgr is None:
    raise FileNotFoundError(f"Could not load '{ST2_FILE}'")

st2_rgb  = cv2.cvtColor(st2_bgr, cv2.COLOR_BGR2RGB)
st2_hsv  = cv2.cvtColor(st2_bgr, cv2.COLOR_BGR2HSV)
st2_H, st2_W = st2_rgb.shape[:2]

# HSV ranges per scene class (OpenCV hue range = 0–179)
COLOUR_RANGES = [
    ('sky',      [((90,  80, 120), (130, 255, 255))]),
    ('sea',      [((80,  60,  80), (110, 255, 220))]),
    ('mountain', [((40,  50,  50), (75,  255, 180))]),
    ('sand',     [((15,  40, 150), (40,  180, 255))]),
]

st2_masks = {}
claimed   = np.zeros(st2_hsv.shape[:2], dtype=np.uint8)

for name, ranges in COLOUR_RANGES:
    m = np.zeros(st2_hsv.shape[:2], dtype=np.uint8)
    for lo, hi in ranges:
        m |= cv2.inRange(st2_hsv, np.array(lo, dtype=np.uint8),
                                  np.array(hi, dtype=np.uint8))
    # Priority chain — each pixel claimed by at most one class
    m = cv2.bitwise_and(m, cv2.bitwise_not(claimed))
    m = cv2.morphologyEx(m, cv2.MORPH_OPEN,  np.ones((5, 5), np.uint8))
    m = cv2.morphologyEx(m, cv2.MORPH_CLOSE, np.ones((7, 7), np.uint8))
    st2_masks[name] = m
    claimed       |= m

ST2_COLOURS  = {'sky': (255, 140, 0), 'sea': (255, 215, 0),
                'mountain': (255, 0, 255), 'sand': (0, 100, 200)}
ST2_MIN_AREA = int(0.005 * st2_H * st2_W)

annotated = st2_rgb.copy()
font = cv2.FONT_HERSHEY_SIMPLEX
kept = 0
for name, mask in st2_masks.items():
    n, _, stats, _ = cv2.connectedComponentsWithStats(mask, connectivity=8)
    for i in range(1, n):
        x, y, w, h, area = stats[i]
        if area < ST2_MIN_AREA:
            continue
        kept  += 1
        colour = ST2_COLOURS[name]
        cv2.rectangle(annotated, (x, y), (x + w, y + h), colour, 2)
        (tw, th), _ = cv2.getTextSize(name, font, 0.5, 1)
        cv2.rectangle(annotated, (x, max(y - th - 6, 0)), (x + tw + 6, y), colour, -1)
        cv2.putText(annotated, name, (x + 3, max(y - 4, th + 2)),
                    font, 0.5, (255, 255, 255), 1, cv2.LINE_AA)

print(f'Stress test 2 — kept {kept} HSV-classified regions')

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].imshow(st2_rgb);   axes[0].set_title('Original — seaside.jpg')
axes[1].imshow(annotated); axes[1].set_title('HSV scene segmentation')
for ax in axes: ax.axis('off')
plt.tight_layout(); plt.show()
# Out:
# Stress test 2 — kept 5 HSV-classified regions

# %% [markdown]
# ---
# # Phase 3 — Multi-Modal Integration
# ### OCR Word Boxes -> Spatial Join with Image Regions -> Unified JSON -> Summary Report
# ---
#
# This phase merges the outputs of Phase 1 (OCR + NLP on `ocr_text`) and
# Phase 2 (`region_records` from connected components) into one structured
# view of the page.
#
# The four steps are:
#
# 1. **3.1** Re-run Tesseract via `pytesseract.image_to_data` to obtain
#    word-level bounding boxes (Phase 1 only used `image_to_string`).
# 2. **3.2** Spatially join each OCR word to the Phase-2 region whose
#    bounding box contains the word's centre.
# 3. **3.3** Draw a unified annotated overlay using the WK6 lab
#    `cv2.rectangle` / `cv2.putText` pattern, and save it with `cv2.imwrite`.
# 4. **3.4** Emit a unified per-region JSON record carrying geometry,
#    OCR text, spaCy entities and VADER sentiment.
# 5. **3.5** Print a short summary report and headline insights.
#
# **Code reuse from WK6 Lab Code (`WK6LabCode.docx`):**
# `cv2.imread`, `cv2.cvtColor`, `cv2.rectangle`, `cv2.putText`, `cv2.imwrite`.
#
# **New external sources (cited inline and in the References section):**
# - `pytesseract.image_to_data` — same OCR pass as Phase 1, richer output.
# - Python `json` standard library — for the structured output.
# - OpenCV `pointPolygonTest` — referenced as the equivalent OpenCV idiom
#   for the containment test (we use the simpler axis-aligned variant).

# %% [markdown]
# ## 3.1  OCR Word-Level Bounding Boxes
#
# `pytesseract.image_to_string` (used in Phase 1) discards geometry. To map
# text onto the regions detected in Phase 2 we need each word's `(left, top,
# width, height)`, which Tesseract exposes via the TSV output mode.
#
# *Reference: pytesseract `image_to_data` — https://github.com/madmaze/pytesseract*
# *Reference: Tesseract TSV output format — https://tesseract-ocr.github.io/tessdoc/Command-Line-Usage.html*

# %%
# -- OCR with word-level bounding boxes ------------------------------------
# Phase 1 used pytesseract.image_to_string (raw text only).
# image_to_data runs the SAME OCR pass but returns per-word geometry
# (left, top, width, height, conf), which is what Phase 3 needs.
#
# Reference: pytesseract.image_to_data
#   https://github.com/madmaze/pytesseract
# Reference: Tesseract TSV output columns
#   https://tesseract-ocr.github.io/tessdoc/Command-Line-Usage.html
#
# img_bgr was loaded in Sec. 2.1 via cv2.imread (WK6 lab pattern).

custom_config = r'--oem 1 --psm 6'   # same engine + page-segmentation as Phase 1

ocr_data = pytesseract.image_to_data(
    img_bgr,
    config=custom_config,
    output_type=pytesseract.Output.DICT,
)

# Keep only rows where Tesseract emitted an actual word with non-zero confidence
words = []
for i in range(len(ocr_data['text'])):
    txt  = ocr_data['text'][i].strip()
    raw_conf = ocr_data['conf'][i]
    try:
        conf = float(raw_conf)
    except (TypeError, ValueError):
        conf = -1.0
    if txt and conf > 0:
        words.append({
            'text' : txt,
            'conf' : round(conf, 1),
            'x'    : int(ocr_data['left'][i]),
            'y'    : int(ocr_data['top'][i]),
            'w'    : int(ocr_data['width'][i]),
            'h'    : int(ocr_data['height'][i]),
        })

print(f'Extracted {len(words)} word-level bounding boxes from OCR.')
print('First 5 words:')
for w in words[:5]:
    print(f"  '{w['text']:<20}' conf={w['conf']:>5}  bbox=({w['x']},{w['y']},{w['w']},{w['h']})")
# Out:
# Extracted 476 word-level bounding boxes from OCR.
# First 5 words:
#   'rte                 ' conf= 45.0  bbox=(231,172,16,6)
#   'prev                ' conf= 45.0  bbox=(253,173,17,7)
#   'XGBoost             ' conf= 78.0  bbox=(395,155,42,8)
#   'Feature             ' conf= 88.0  bbox=(441,155,36,8)
#   'Importance          ' conf= 87.0  bbox=(482,151,55,26)

# %% [markdown]
# ## 3.2  Spatial Join — Map Words to Regions
#
# A word "belongs" to a region if the centre of its OCR bounding box lies
# inside the region's rectangle. Phase 2's regions come from
# `cv2.connectedComponentsWithStats`, so they are already axis-aligned —
# a few lines of arithmetic are enough; no extra OpenCV calls needed.
#
# *Reference: OpenCV equivalent for arbitrary contours is `cv2.pointPolygonTest` —
# https://docs.opencv.org/4.x/dd/d49/tutorial_py_contour_features.html*

# %%
# -- Spatial join: assign each OCR word to a Phase-2 image region ----------
# Pure-Python point-in-rectangle test (the regions are axis-aligned).
# OpenCV equivalent for general contours: cv2.pointPolygonTest.

def _centre(word):
    return (word['x'] + word['w'] // 2, word['y'] + word['h'] // 2)

def _contains(region, point):
    rx, ry, rw, rh, _ = region
    px, py = point
    return rx <= px <= rx + rw and ry <= py <= ry + rh

# Build region_id -> [words] mapping. Iterate smallest-first so a word that
# falls inside both a tight text_line and the paragraph that wraps it is
# attributed to the tighter region.
regions_small_first = sorted(
    list(enumerate(region_records)),
    key=lambda ir: ir[1][2] * ir[1][3],
)

region_to_words = {i: [] for i, _ in regions_small_first}
unassigned = []

for w in words:
    centre = _centre(w)
    matched_id = None
    for i, region in regions_small_first:
        if _contains(region, centre):
            matched_id = i
            break
    if matched_id is None:
        unassigned.append(w)
    else:
        region_to_words[matched_id].append(w)

# Coverage stats
total = len(words)
assigned = total - len(unassigned)
print(f'Words assigned to a region : {assigned}/{total} ({assigned/total:.0%})')
print(f'Words outside any region   : {len(unassigned)}')

# Show top-5 most word-dense regions
dense = sorted(
    ((i, len(ws)) for i, ws in region_to_words.items()),
    key=lambda t: t[1], reverse=True
)[:5]
print()
print('Top-5 word-dense regions:')
for rid, n in dense:
    if n == 0:
        break
    x, y, w_, h_, rtype = region_records[rid]
    print(f'  region #{rid:>3}  type={rtype:<10}  bbox=({x},{y},{w_},{h_})  words={n}')
# Out:
# Words assigned to a region : 476/476 (100%)
# Words outside any region   : 0
#
# Top-5 word-dense regions:
#   region #  1  type=paragraph   bbox=(137,1180,1428,519)  words=128
#   region #  3  type=paragraph   bbox=(137,855,1427,319)  words=82
#   region #  5  type=paragraph   bbox=(137,1702,1428,163)  words=71
#   region #  4  type=paragraph   bbox=(137,664,1428,192)  words=66
#   region #  6  type=header      bbox=(138,1906,1427,92)  words=44

# %% [markdown]
# ## 3.3  Unified Annotated Visualisation
#
# Region rectangles (thick, colour-coded by type) and OCR word rectangles
# (thin yellow) are drawn on the same canvas. Text labels for each region
# follow the same `cv2.putText` styling used in Sec. 2.4 and in the WK6
# lab's annotated-image example.
#
# *WK6 Lab Code reused: `cv2.imread`, `cv2.cvtColor`, `cv2.rectangle`, `cv2.putText`, `cv2.imwrite`.*

# %%
# -- Unified annotated overlay: region boxes + OCR word boxes --------------
# Uses WK6 lab patterns end-to-end (cv2.rectangle, cv2.putText, cv2.imwrite).

unified = img_rgb.copy()
font = cv2.FONT_HERSHEY_SIMPLEX

# 1. Region rectangles (thick) -- same palette as Sec. 2.4
for (x, y, w_, h_, rtype) in region_records:
    colour = REGION_COLOURS.get(rtype, (200, 200, 200))
    cv2.rectangle(unified, (x, y), (x + w_, y + h_), colour, 3)

# 2. OCR word rectangles (thin yellow) layered on top
WORD_COLOUR = (255, 215, 0)
for w in words:
    cv2.rectangle(
        unified,
        (w['x'], w['y']),
        (w['x'] + w['w'], w['y'] + w['h']),
        WORD_COLOUR, 1,
    )

# 3. Region-type labels -- cv2.putText pattern from WK6
for (x, y, w_, h_, rtype) in region_records:
    colour = REGION_COLOURS.get(rtype, (200, 200, 200))
    label  = rtype.replace('_', ' ').title()
    (tw, th), _ = cv2.getTextSize(label, font, 0.55, 1)
    cv2.rectangle(unified, (x, max(y - th - 6, 0)), (x + tw + 6, y), colour, -1)
    cv2.putText(unified, label, (x + 3, max(y - 4, th + 2)),
                font, 0.55, (255, 255, 255), 1, cv2.LINE_AA)

plt.figure(figsize=(14, 18))
plt.imshow(unified)
plt.title('Phase 3 - Unified View: Image Regions (thick) + OCR Word Boxes (thin yellow)')
plt.axis('off')
plt.tight_layout()
plt.show()

# -- Save the unified figure to disk (WK6 lab: cv2.imwrite) ----------------
OUT_PNG = 'ca2_doc_phase3_unified.png'
cv2.imwrite(OUT_PNG, cv2.cvtColor(unified, cv2.COLOR_RGB2BGR))
print(f"Saved unified annotated image to '{OUT_PNG}'")
# Out:
# Saved unified annotated image to 'ca2_doc_phase3_unified.png'

# %% [markdown]
# ## 3.4  Structured Multi-Modal Output (JSON)
#
# Each Phase-2 region is emitted as a JSON record carrying:
#
# | Field | Source |
# |-------|--------|
# | `region_id`, `region_type`, `bbox` | Phase 2 — `cv2.connectedComponentsWithStats` (Sec. 2.3) |
# | `ocr_text`, `word_count`           | Phase 3.1 + 3.2 spatial join                          |
# | `entities`                         | spaCy NER (Phase 1, Sec. 4)                           |
# | `sentiment`                        | VADER (Phase 1, Sec. 10)                              |
#
# The whole document is then written to disk as a single JSON file —
# this is the "unified pipeline output" asked for by the Week 4 brief.
#
# *Reference: Python `json` standard library — https://docs.python.org/3/library/json.html*

# %%
# -- Build the unified multi-modal record per region -----------------------
# Combines Phase-2 geometry with Phase-1 NLP outputs (NER, VADER).
#
# Reference: Python json module
#   https://docs.python.org/3/library/json.html

import json

multimodal = []
for i, (x, y, w_, h_, rtype) in enumerate(region_records):
    region_words = region_to_words.get(i, [])
    region_text  = ' '.join(w['text'] for w in region_words)

    # spaCy NER on this region's text only (re-uses `nlp` from Phase 1 cell 4)
    ents = []
    if region_text.strip():
        ents = [
            {'text': e.text, 'label': e.label_}
            for e in nlp(region_text).ents
        ]

    # VADER sentiment on this region's text (re-uses `sia` from Sec. 10)
    if region_text.strip():
        sent = sia.polarity_scores(region_text)
    else:
        sent = {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}

    multimodal.append({
        'region_id'   : i,
        'region_type' : rtype,
        'bbox'        : {'x': int(x), 'y': int(y), 'w': int(w_), 'h': int(h_)},
        'word_count'  : len(region_words),
        'ocr_text'    : region_text,
        'entities'    : ents,
        'sentiment'   : {k: round(v, 3) for k, v in sent.items()},
    })

# Persist the whole document to disk
OUT_JSON = 'ca2_doc_multimodal.json'
with open(OUT_JSON, 'w', encoding='utf-8') as f:
    json.dump({
        'source_image' : IMAGE_FILE,
        'page_size'    : {'height': int(H), 'width': int(W)},
        'n_regions'    : len(multimodal),
        'n_words'      : len(words),
        'regions'      : multimodal,
    }, f, indent=2, ensure_ascii=False)

print(f"Wrote '{OUT_JSON}' -- {len(multimodal)} regions, {len(words)} OCR words.")

# -- Preview the first text-bearing region ---------------------------------
preview = next((r for r in multimodal if r['word_count'] > 0), None)
if preview:
    print()
    print('=== Sample region record ===')
    print(json.dumps(preview, indent=2, ensure_ascii=False)[:1200])
else:
    print('No text-bearing region found to preview.')
# Out:
# Wrote 'ca2_doc_multimodal.json' -- 19 regions, 476 OCR words.
#
# === Sample region record ===
# {
#   "region_id": 1,
#   "region_type": "paragraph",
#   "bbox": {
#     "x": 137,
#     "y": 1180,
#     "w": 1428,
#     "h": 519
#   },
#   "word_count": 128,
#   "ocr_text": "e Only two time periods were analysed e Spatial dependencies were not modelled US County Homeownership Rate (2019 ACS) e ACS estimates contain sampling variability Homeownership Rate ee se This study developed a machine learning framework to predict U.S. county-level homeownership rates using ACS data. The results demonstrate that county-level homeownership ° can be predicted with high accuracy using socioeconomic, de- mographic, and housing characteristics. Among the evaluated models, Random Forest achieved the strongest performance Based on the results of this study, it is clear that county-level (R? = 0.880), outperforming both neural network and XG- homeownership rates in the United States can be effectively Boost models and highlighting the effectiveness of ensemble predicted using a combination of current and historical socioe- ee methods for structured socioeconomic data.",
#   "entities": [
#     {
#       "text": "Only two",
#       "label": "CARDINAL"
#     },
#     {
#       "text": "US County Homeownership Rate",
#       "label"

# %% [markdown]
# ## 3.5  Summary Report — Counts, Entities, Sentiment
#
# A compact table showing per-region geometry, word count, entity count,
# sentiment polarity and a short text snippet, followed by headline insights
# across the whole page.

# %%
# -- Per-region summary table ----------------------------------------------
summary_rows = []
for r in multimodal:
    summary_rows.append({
        'Region'   : f"#{r['region_id']} {r['region_type']}",
        'BBox'     : f"({r['bbox']['x']},{r['bbox']['y']}) {r['bbox']['w']}x{r['bbox']['h']}",
        'Words'    : r['word_count'],
        'Entities' : len(r['entities']),
        'Compound' : r['sentiment']['compound'],
        'Snippet'  : (r['ocr_text'][:60] + '...') if len(r['ocr_text']) > 60 else r['ocr_text'],
    })

summary_df = pd.DataFrame(summary_rows)
print('=== Phase 3 Region Summary ===')
print(summary_df.to_string(index=False))

# -- Headline insights ------------------------------------------------------
text_regions = [r for r in multimodal if r['word_count'] > 0]
all_entities = [e for r in multimodal for e in r['entities']]
ent_counts   = Counter(e['label'] for e in all_entities)

print()
print('=== Headline Insights ===')
print(f'  Regions detected         : {len(multimodal)}')
print(f'  Regions carrying text    : {len(text_regions)}')
print(f'  Words placed in a region : {sum(r["word_count"] for r in multimodal)}/{len(words)}')
print(f'  Total NE mentions        : {len(all_entities)}')
if ent_counts:
    print('  Top entity types         : ' +
          ', '.join(f'{lbl}={cnt}' for lbl, cnt in ent_counts.most_common(5)))
if text_regions:
    densest = max(text_regions, key=lambda r: r['word_count'])
    print(f'  Densest text region      : #{densest["region_id"]} '
          f'({densest["region_type"]}) -- {densest["word_count"]} words')
    overall_compound = sum(r['sentiment']['compound'] for r in text_regions) / len(text_regions)
    print(f'  Mean region sentiment    : compound = {overall_compound:+.3f}')
# Out:
# === Phase 3 Region Summary ===
#        Region                BBox  Words  Entities  Compound                                                         Snippet
#      #0 other     (0,0) 1700x2200      0         0     0.000
#  #1 paragraph (137,1180) 1428x519    128        12     0.917 e Only two time periods were analysed e Spatial dependencies...
#  #2 paragraph  (137,141) 1447x442     21         3     0.361 rte prev XGBoost Feature Importance (Enhanced with Historica...
#  #3 paragraph  (137,855) 1427x319     82         5     0.739 US County Homeownership Rate (2022 ACS) tabular socioeconomi...
#  #4 paragraph  (137,664) 1428x192     66         6     0.617 conomic conditions in shaping county-level homeownership and...
#  #5 paragraph (137,1702) 1428x163     71         7     0.920 conomic, demographic, and housing characteristics. All three...
#     #6 header  (138,1906) 1427x92     44         1     0.296 Among the predictor variables, prior-year homeownership spat...
#     #7 figure  (245,1291) 379x214      6         0     0.000                                                   x . A ws, ~ °
#     #8 figure   (973,199) 365x214      1         0     0.000                                                             Pec
#     #9 figure   (257,913) 364x213      3         0     0.000                                                           ” = ~
#     #10 other    (465,713) 928x52      9         0     0.000 that local economic conditions, achieved the highest predict...
# #11 text_line    (868,597) 696x59     17         0     0.796 as the most influential factors. These results highlight the...
# #12 text_line   (138,1872) 695x26      7         0     0.000    stantial variance in homeownership outcomes across counties.
# #13 text_line   (897,1872) 667x26      8         0     0.178         Future research could extend this work by incorporating
#     #14 other   (996,1119) 402x20      0         0     0.000
# #15 text_line    (287,608) 398x20      6         3     0.361                       Fig. 10. Random Forest feature importance
# #16 text_line   (1044,501) 346x20      5         1     0.000                             Fig. 11. Evolution of homeownership
#     #17 other   (872,1959) 301x19      0         0     0.000
# #18 text_line  (1101,1333) 231x20      2         0     0.000                                                VIII. CONCLUSION
#
# === Headline Insights ===
#   Regions detected         : 19
#   Regions carrying text    : 16
#   Words placed in a region : 476/476
#   Total NE mentions        : 38
#   Top entity types         : ORG=14, CARDINAL=11, DATE=5, PERSON=5, GPE=2
#   Densest text region      : #1 (paragraph) -- 128 words
#   Mean region sentiment    : compound = +0.324

# %% [markdown]
# ---
# # References
#
# External libraries and techniques used in this notebook beyond the WK2 and WK6
# lab code:
#
# **Lab code reused or adapted directly**
# - WK6 Lab Code (`WK6LabCode.docx`) — `cv2.imread`, `cv2.cvtColor`,
#   `cv2.GaussianBlur`, `cv2.threshold` (BINARY / BINARY_INV / OTSU),
#   `cv2.rectangle`, `cv2.putText`, `cv2.imwrite`.
# - WK2 Lab Code (`Wk2LaCode.docx`, `Wk2Lb.docx`) — spaCy / NLTK tokenisation,
#   stopword handling, NER, `noun_chunks`, dependency parsing, displaCy rendering.
#
# **Python NLP libraries**
# - pytesseract (Tesseract OCR Python wrapper) — https://github.com/madmaze/pytesseract
# - spaCy NLP library and `en_core_web_sm` model — https://spacy.io/models/en
# - NLTK — https://www.nltk.org/
# - VADER sentiment (Hutto & Gilbert, 2014) —
#   https://www.nltk.org/api/nltk.sentiment.vader.html
# - scikit-learn `CountVectorizer` / `TfidfVectorizer` —
#   https://scikit-learn.org/stable/modules/feature_extraction.html#text-feature-extraction
#
# **OpenCV image-processing techniques used beyond the WK6 lab**
# - Canny edge detection — https://docs.opencv.org/4.x/da/d22/tutorial_py_canny.html
# - Shi–Tomasi corners (`goodFeaturesToTrack`) —
#   https://docs.opencv.org/4.x/d4/d8c/tutorial_py_shi_tomasi.html
# - Morphological transformations (`getStructuringElement`, `morphologyEx`) —
#   https://docs.opencv.org/4.x/d9/d61/tutorial_py_morphological_ops.html
# - Connected components (`connectedComponentsWithStats`) —
#   https://docs.opencv.org/4.x/d3/dc0/group__imgproc__shape.html
# - Otsu thresholding —
#   https://docs.opencv.org/4.x/d7/d4d/tutorial_py_thresholding.html
# - HSV colour-space segmentation (`inRange`) —
#   https://docs.opencv.org/4.x/df/d9d/tutorial_py_colorspaces.html
#
# **PDF rendering (Section 0)**
# Used to render the source PDF to a 200 DPI PNG so the cv2.imread + WK6-lab
# pipeline can ingest it. The notebook tries `pypdfium2` first and falls back
# to PyMuPDF if it isn't installed.
# - pypdfium2 (Google PDFium binding, preferred — no system deps) —
#   https://pypdfium2.readthedocs.io/en/stable/
# - PyMuPDF / `fitz` (Artifex MuPDF binding, fallback) —
#   https://pymupdf.readthedocs.io/en/latest/
#
# **Phase 3 — Multi-Modal Integration sources**
# - pytesseract `image_to_data` (word-level OCR boxes) —
#   https://github.com/madmaze/pytesseract
# - Tesseract TSV output format (column meanings: level, left, top, width,
#   height, conf, text) —
#   https://tesseract-ocr.github.io/tessdoc/Command-Line-Usage.html
# - OpenCV `pointPolygonTest` (point-in-contour test referenced as the
#   general-contour equivalent of the axis-aligned check used in Sec. 3.2) —
#   https://docs.opencv.org/4.x/dd/d49/tutorial_py_contour_features.html
# - Python `json` standard library (structured Phase-3 output in Sec. 3.4) —
#   https://docs.python.org/3/library/json.html
#
# **Region classification — density-based figure detection (Sec. 2.3)**
# - Wong, K. Y., Casey, R. G., & Wahl, F. M. (1982). "Document analysis
#   system." IBM Journal of Research and Development, 26(6), 647–656.
#   https://doi.org/10.1147/rd.266.0647 — foundational paper for
#   Run-Length Smoothing + foreground-density classification, the
#   classical (non-deep-learning) approach to printed-page layout.
# - Bloomberg, D. S. — Leptonica papers on multiresolution morphology
#   for document image analysis (the same halftone/figure detection
#   approach Tesseract uses internally) —
#   https://www.leptonica.org/papers.html
#
# **Document-layout-analysis recipe**
# The "binarise -> morphological close (horizontal kernel) -> connected components
# -> bounding boxes" pipeline used in Sections 2.2–2.4 is the standard recipe
# from OpenCV's text-detection examples and most introductory document-analysis
# tutorials.
